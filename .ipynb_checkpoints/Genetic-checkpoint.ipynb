# %% [markdown]
# # Computer Assignment #2 Game Report
# # AI course - Fall 1400
# <h2>By Kianoush Arshi<br>Std ID: 810198438</h2>

# %% [markdown]
# <h2>Part 1: Genes and Chromosomes</h2>
# In this algorithm we have 3 different classes of data:<br>
# <li>Genome, which is the smallest and mine is each cell of the board.<br>
# <li>Chromosme, which is a cluster of genes together and mine is a 9 in 9 board.<br>
# <li>Population, which is a list of chromosmes and my population size is 200.<br></li>
#
# <h2>Genome</h2>
# <p>Each cell is a genome, in the algorithms mutation function we swap 2 genes in the same chromosome and in the cross over we swap a group of genes between two chromosomes.<br></p>
#
# <h2>Chromosome</h2>
# <p>
#     Each chromosome is a possible solution to our problem.<br>
#     We can find out if a solution is found using a fitness function which is defined as follows:<br>
#     <li>Get the count of duplicate numbers in each column and divide them by (9*9)</li>
#     <li>Get the count of duplicate numbers in each 3by3 block and divide them by (9*9)</li>
#     <li>Check if there is any duplicates:
#         <li>If there isn't any: set fitness to 1 and return.
#         <li>If there is: return the multitude of block_sum and col_sum as fitness.
#     </li>
# </p>
#
# <h2>Population</h2>
# <p>
#     We have a ppulation size of 200. Initial population is generated randomly with the only two constraints of not having duplicated any of the fixed values in a block, row or column and not inputted more than 9 times.<br>
#     Each generation, we take 20% of the top(fittesst) chromosomes and keep them as elites in the next generation. Using these elites, we create children by randomly crossing over two of them and possibly mutating the child.<br>
#     <h4>Cross Over:</h4>
#     <p>
#         A child is created using a cross over between two randomly selected chromosomes and then using two randomly generated cross over points, switched genes between these points in each row.
#         The aforementioned approach for cross over had some problems, only the elites had a chance to be a parent. This might cause the algorithm to get stuck in local minima. Thus a new approach is introduced:<br>
#         Have a competition between two randomly chosen chromosomes and give the weaker one a chance to be chosen reducing the chance for the population to go stale.
#     </p>
#     <h4>Muation:</h4>
#     <p>
#         In general, optimization solving algorithms converge to a local minimum.  To get out of this local minimum in a Genetic Algorithm, you can use mutations. The higher the mutation rate is, the more 'space' will be searched and the higher the chance that the global minimum is found. But if the mutation rate is too high, the algorithm won't converge anymore.<br>
#         The cross overed child is then mutated with an adaptive mutation rate which chaanges each time we encounter a successful mutation and resets each time we encounter stale population.<br>
#         Significant progress toward the fitness function's optimum, generally, can only happen in a narrow band of the mutation step size sigma. That narrow band is called evolution window.<br>
#         There are three well-known methods to adapt the mutation step size σ in evolution strategies:<br>
#             <li>(1/5-th) Success Rule</li>
#             <li>Self-Adaptation (for example through log-normal mutations)</li>
#             <li>Cumulative Step Size Adaptation (CSA)</li>
#     </p>
#     <h4>Handling Stale Population:</h4>
#     <p>
#         To detect a stale population, we have a counter which counts each time we see that the two best chromosomes have the same fitness. If this counter reaches 100, we reset the algorithm with new initial population and the base mutation rate.
#     </p>
# </p>

# %%
def read_file(filename : str) -> list() :
    file = open(filename, 'r+')
    init_board = []
    for line in file.readlines():
        init_board.append([int(i) for i in line.split()])
        
    return init_board

def print_chromosome(chromosome):
    if chromosome == None:
        return
    for i in range(len(chromosome)):
        for j in range(len(chromosome[0])):
            print(chromosome[i][j], end = " ")
        print()
    print()

# %%
def is_row_duplicate(row, value, chromosome):
    for column in range(0, 9):
        if chromosome[row][column] == value:
            return True
    return False

def is_column_duplicate(column, value, chromosome):
    for row in range(0, 9):
        if chromosome[row][column] == value:
            return True
    return False

def is_block_duplicate(row, column, value, chromosome):
    i = 3 * (int(row / 3))
    j = 3 * (int(column / 3))

    if ((chromosome[i][j] == value)
        or (chromosome[i][j + 1] == value)
        or (chromosome[i][j + 2] == value)
        or (chromosome[i + 1][j] == value)
        or (chromosome[i + 1][j + 1] == value)
        or (chromosome[i + 1][j + 2] == value)
        or (chromosome[i + 2][j] == value)
        or (chromosome[i + 2][j + 1] == value)
        or (chromosome[i + 2][j + 2] == value)):
        return True
    else:
        return False

def make_index(v):
    if v <= 2:
        return 0
    elif v <= 5:
        return 3
    else:
        return 6
    
def find_unused(parent_row, remaining):
    for i in range(0, len(parent_row)):
        if (parent_row[i] in remaining):
            return i

def find_value(parent_row, value):
    for i in range(0, len(parent_row)):
        if (parent_row[i] == value):
            return i

# %%
def compete(chromosome1, chromosome2):

        # Find the fittest and the weakest.
        if (chromosome1[0] > chromosome2[0]):
            fittest = chromosome1[1]
            weakest = chromosome2[1]
        else:
            fittest = chromosome2[1]
            weakest = chromosome1[1]

        selection_rate = 0.80
        r = random.uniform(0, 1.1)
        while (r > 1):  # Outside [0, 1] boundary. Choose another.
            r = random.uniform(0, 1.1)
        if (r < selection_rate):
            return fittest
        else:
            return weakest

# %%
import random
from copy import deepcopy
from math import floor
import numpy as np

random.seed()

class SudokuSolver():

    def __init__(self, init_board):
        self.fixed_values = init_board
        self.solved = 0
        self.pop_size = 200  # population size
        self.elite_percentage = 10 # keep x% best of parents in the new population
        self.Ng = 10000  # Number of generations.
        self.m_count = 0  # Number of mutations.
        self.ans = []
        
        # Cross over probability
        self.pc = 0.7
        # Mutation parameters.
        self.phi = 0
        self.sigma = 1
        self.pm = 0.06

        # Create an initial population.
        self.chromosomes = self.generate_initial_population()
        return
    
    def generate_initial_population(self):
        self.stale = 0
        init_pop = []
        
        # Determine the legal values that each square can take.
        helper = [[[] for j in range(0, 9)] for i in range(0, 9)]
        for row in range(0, 9):
            for column in range(0, 9):
                for value in range(1, 10):
                    if ((self.fixed_values[row][column] == 0) and not 
                        (is_column_duplicate(column, value, self.fixed_values) or 
                         is_block_duplicate(row, column, value, self.fixed_values) or 
                         is_row_duplicate(row, value, self.fixed_values))):
                        # Value is available.
                        helper[row][column].append(value)
                    elif self.fixed_values[row][column] != 0:
                        # Given/known value from file.
                        helper[row][column].append(self.fixed_values[row][column])
                        break

        # Seed a new population.
        for p in range(0, self.pop_size):
            chromosome = []
            for i in range(0, 9):  # New row in candidate.
                row = [0]*9

                # Fill in the givens.
                for j in range(0, 9):  # New column j value in row i.

                    # If value is already given, don't change it.
                    if self.fixed_values[i][j] != 0:
                        row[j] = self.fixed_values[i][j]
                    # Fill in the gaps using the helper board.
                    elif self.fixed_values[i][j] == 0:
                        row[j] = helper[i][j][random.randint(0, len(helper[i][j]) - 1)]

                # If we don't have a valid board, then try again. max iteration 500,000
                # There must be no duplicates in the row.
                ii = 0
                while len(list(set(row))) != Nd:
                    ii += 1
                    if ii > 500000:
                        return 0
                    for j in range(0, 9):
                        if self.fixed_values[i][j] == 0:
                            row[j] = helper[i][j][random.randint(0, len(helper[i][j]) - 1)]

                chromosome.append(row)
            init_pop.append(chromosome)

        print_chromosome(init_pop[0])
        print("Initial fitness:", self.get_fitness(init_pop[0]))
        return init_pop
    
    def cross_over(self, chromosome1, chromosome2):
        # Make a copy of the parent genes.
        child1 = deepcopy(chromosome1)
        child2 = deepcopy(chromosome2)

        # Pick a crossover point. Crossover must have at least 1 row (and at most 8) rows.
        crossover_point1 = random.randint(0, 8)
        crossover_point2 = random.randint(1, 9)
        while (crossover_point1 == crossover_point2):
            crossover_point1 = random.randint(0, 8)
            crossover_point2 = random.randint(1, 9)

        if (crossover_point1 > crossover_point2):
            temp = crossover_point1
            crossover_point1 = crossover_point2
            crossover_point2 = temp
            
        for i in range(crossover_point1, crossover_point2):
            child1[i], child2[i] = self.crossover_rows(child1[i], child2[i])

        return child1, child2
                    
    def crossover_rows(self, row1, row2):
        child_row1 = [0]*9
        child_row2 = [0]*9

        remaining = [i for i in range(1, 10)]
        cycle = 0

        while ((0 in child_row1) and (0 in child_row2)):
            if (cycle % 2 == 0):  # Even cycles.
                # Assign next unused value.
                index = find_unused(row1, remaining)
                start = row1[index]
                remaining.remove(row1[index])
                child_row1[index] = row1[index]
                child_row2[index] = row2[index]
                next = row2[index]

                while (next != start):  # While cycle not done...
                    index = find_value(row1, next)
                    child_row1[index] = row1[index]
                    remaining.remove(row1[index])
                    child_row2[index] = row2[index]
                    next = row2[index]

                cycle += 1

            else:  # Odd cycle - flip values.
                index = find_unused(row1, remaining)
                start = row1[index]
                remaining.remove(row1[index])
                child_row1[index] = row2[index]
                child_row2[index] = row1[index]
                next = row2[index]

                while (next != start):  # While cycle not done...
                    index = find_value(row1, next)
                    child_row1[index] = row2[index]
                    remaining.remove(row1[index])
                    child_row2[index] = row1[index]
                    next = row2[index]

                cycle += 1

        return child_row1, child_row2

    def mutate(self, chromosome):
        prob = random.random()
        if (prob < self.pm):  # Mutate.
            row1, col1 = (random.randint(0, 8), random.randint(0, 8))
            row2, col2 = (random.randint(0, 8), random.randint(0, 8))

            while (row1, col1) == (row2, col2):
                row1, col1 = (random.randint(0, 8), random.randint(0, 8))
                row2, col2 = (random.randint(0, 8), random.randint(0, 8))
            row2 = row1

            # Check if the two places are not fixed
            if self.fixed_values[row1][col1] == 0 and self.fixed_values[row2][col2] == 0:
                temp_chromosome = deepcopy(chromosome)
                temp = temp_chromosome[row2][col2]
                temp_chromosome[row2][col2] = temp_chromosome[row1][col1]
                temp_chromosome[row1][col1] = temp
                # and we are not lowering fitness.
                if self.get_fitness(temp_chromosome) < self.get_fitness(chromosome):
                    self.m_count += 1
                    self.phi += 1
                    chromosome = deepcopy(temp_chromosome)

        return chromosome
        
        
    def get_fitness(self, chromosome):
        fitness = 0
        
        for j in range(0, 9):
            values = set()
            
            # For each column....
            for i in range(0, 9):
                values.add(chromosome[i][j])
            fitness += 9-len(values)
            values.clear()

            # For each row....
            for i in range(9):
                values.add(chromosome[j][i])
            fitness += 9-len(values)
            values.clear()

        # For each block...
        for i in range(0, 9, 3):
            values = set()
            for j in range(0, 9, 3):
                values.add(chromosome[i][j])
                values.add(chromosome[i][j + 1])
                values.add(chromosome[i][j + 2])

                values.add(chromosome[i + 1][j])
                values.add(chromosome[i + 1][j + 1])
                values.add(chromosome[i + 1][j + 2])

                values.add(chromosome[i + 2][j])
                values.add(chromosome[i + 2][j + 1])
                values.add(chromosome[i + 2][j + 2])
            
            fitness += 9-len(values)

        return fitness
    
    def generate_new_population(self, generation):
        sorted_chromosomes = [(self.get_fitness(chromosome), chromosome) for chromosome in self.chromosomes]
        sorted_chromosomes.sort()
        
        # Check for stale population.
        if (sorted_chromosomes[0] != sorted_chromosomes[1]):
            self.stale = 0
        else:
            self.stale += 1

        # Re-seed the population if 100 generations have passed
        # with the fittest two candidates always having the same fitness.
        if (self.stale >= 100):
            print("The population has gone stale. Re-seeding...")
            self.sigma = 1
            self.phi = 0
            self.pm = 0.06
            return self.generate_initial_population()

        elites = sorted_chromosomes[:floor((self.elite_percentage / 100) * (self.pop_size))]
        print("Generation {}. Best fitness: {}. Second best: {}".format(generation, elites[0][0], elites[1][0]))
        if (sorted_chromosomes[0][0] == 1): #no intersections in the best chromosome
            self.solved = 1
            self.ans = sorted_chromosomes[0][1]
            return sorted_chromosomes[0]

        new_pop = [chromosome[1] for chromosome in elites] # add elites

        # Create the rest of the candidates.
        while (len(new_pop) < self.pop_size):
            # Select parents from population via a tournament.
            potential_parents = random.sample(sorted_chromosomes, 4)
            parent1 = compete(potential_parents[0], potential_parents[1])
            parent2 = compete(potential_parents[2], potential_parents[3])

            child1, child2 = self.cross_over(parent1, parent2)

            mutated_child1 = self.mutate(child1)
            mutated_child2 = self.mutate(child2)
            new_pop.append(mutated_child1)
            new_pop.append(mutated_child2)

        return new_pop

    def solve(self):        
        for generation in range(0, self.Ng):
            # Create the next population.
            self.chromosomes = self.generate_new_population(generation)
            # Calculate new adaptive mutation rate (based on Rechenberg's 1/5 success rule).
            # This is to stop too much mutation as the fitness progresses towards unity.
            if (self.m_count == 0):
                self.phi = 0  # Avoid divide by zero.
            else:
                self.phi = self.phi / self.m_count

            if (self.phi > 0.2):
                self.sigma = self.sigma / 0.998
            elif (self.phi < 0.2):
                self.sigma = self.sigma * 0.998
                
            self.pm = abs(np.random.normal(loc=0.0, scale=self.sigma, size=None))
                
            if self.solved:
                return self.ans

        print("No solution found.")
        return None
    
    

from time import time

if __name__ == '__main__':

    sudoku_solver = SudokuSolver(read_file("Test1.txt"))

    start = time()

    print_chromosome(sudoku_solver.solve())

    end = time()

    print("Time taken:", (end-start))
# Out:
# 8 4 6 9 5 3 1 2 7
# 9 1 7 6 8 2 3 5 4
# 9 5 3 1 7 4 8 2 6
# 7 9 4 8 2 1 6 3 5
# 6 3 5 4 7 1 2 9 8
# 1 6 9 5 7 3 4 2 8
# 5 3 1 2 4 8 7 6 9
# 2 4 8 7 9 6 5 1 3
# 6 7 9 4 1 5 3 8 2
#
# Initial fitness: 14
# Generation 0. Best fitness: 6. Second best: 8
# Generation 1. Best fitness: 6. Second best: 8
# Generation 2. Best fitness: 6. Second best: 6
# Generation 3. Best fitness: 6. Second best: 6
# Generation 4. Best fitness: 4. Second best: 6
# Generation 5. Best fitness: 4. Second best: 6
# Generation 6. Best fitness: 4. Second best: 6
# Generation 7. Best fitness: 4. Second best: 6
# Generation 8. Best fitness: 4. Second best: 6
# Generation 9. Best fitness: 4. Second best: 6
# Generation 10. Best fitness: 4. Second best: 6
# Generation 11. Best fitness: 4. Second best: 6
# Generation 12. Best fitness: 4. Second best: 6
# Generation 13. Best fitness: 4. Second best: 6
# Generation 14. Best fitness: 4. Second best: 6
# Generation 15. Best fitness: 4. Second best: 6
# Generation 16. Best fitness: 4. Second best: 5
# Generation 17. Best fitness: 4. Second best: 5
# Generation 18. Best fitness: 4. Second best: 5
# Generation 19. Best fitness: 4. Second best: 5
# Generation 20. Best fitness: 4. Second best: 5
# Generation 21. Best fitness: 4. Second best: 5
# Generation 22. Best fitness: 4. Second best: 4
# Generation 23. Best fitness: 4. Second best: 4
# Generation 24. Best fitness: 4. Second best: 4
# Generation 25. Best fitness: 4. Second best: 4
# Generation 26. Best fitness: 4. Second best: 4
# Generation 27. Best fitness: 4. Second best: 4
# Generation 28. Best fitness: 4. Second best: 4
# Generation 29. Best fitness: 4. Second best: 4
# Generation 30. Best fitness: 4. Second best: 4
# Generation 31. Best fitness: 4. Second best: 4
# Generation 32. Best fitness: 4. Second best: 4
# Generation 33. Best fitness: 4. Second best: 4
# Generation 34. Best fitness: 4. Second best: 4
# Generation 35. Best fitness: 4. Second best: 4
# Generation 36. Best fitness: 4. Second best: 4
# Generation 37. Best fitness: 4. Second best: 4
# Generation 38. Best fitness: 4. Second best: 4
# Generation 39. Best fitness: 4. Second best: 4
# Generation 40. Best fitness: 4. Second best: 4
# Generation 41. Best fitness: 4. Second best: 4
# Generation 42. Best fitness: 4. Second best: 4
# Generation 43. Best fitness: 4. Second best: 4
# Generation 44. Best fitness: 4. Second best: 4
# Generation 45. Best fitness: 4. Second best: 4
# Generation 46. Best fitness: 4. Second best: 4
# Generation 47. Best fitness: 4. Second best: 4
# Generation 48. Best fitness: 4. Second best: 4
# Generation 49. Best fitness: 4. Second best: 4
# Generation 50. Best fitness: 4. Second best: 4
# Generation 51. Best fitness: 4. Second best: 4
# Generation 52. Best fitness: 4. Second best: 4
# Generation 53. Best fitness: 4. Second best: 4
# Generation 54. Best fitness: 4. Second best: 4
# Generation 55. Best fitness: 4. Second best: 4
# Generation 56. Best fitness: 4. Second best: 4
# Generation 57. Best fitness: 4. Second best: 4
# Generation 58. Best fitness: 4. Second best: 4
# Generation 59. Best fitness: 4. Second best: 4
# Generation 60. Best fitness: 4. Second best: 4
# Generation 61. Best fitness: 4. Second best: 4
# Generation 62. Best fitness: 4. Second best: 4
# Generation 63. Best fitness: 4. Second best: 4
# Generation 64. Best fitness: 4. Second best: 4
# Generation 65. Best fitness: 4. Second best: 4
# Generation 66. Best fitness: 4. Second best: 4
# Generation 67. Best fitness: 4. Second best: 4
# Generation 68. Best fitness: 3. Second best: 4
# Generation 69. Best fitness: 3. Second best: 3
# Generation 70. Best fitness: 3. Second best: 3
# Generation 71. Best fitness: 3. Second best: 3
# Generation 72. Best fitness: 3. Second best: 3
# Generation 73. Best fitness: 3. Second best: 3
# Generation 74. Best fitness: 3. Second best: 3
# Generation 75. Best fitness: 3. Second best: 3
# Generation 76. Best fitness: 3. Second best: 3
# Generation 77. Best fitness: 3. Second best: 3
# Generation 78. Best fitness: 3. Second best: 3
# Generation 79. Best fitness: 3. Second best: 3
# Generation 80. Best fitness: 3. Second best: 3
# Generation 81. Best fitness: 3. Second best: 3
# Generation 82. Best fitness: 3. Second best: 3
# Generation 83. Best fitness: 3. Second best: 3
# Generation 84. Best fitness: 3. Second best: 3
# Generation 85. Best fitness: 3. Second best: 3
# Generation 86. Best fitness: 3. Second best: 3
# Generation 87. Best fitness: 3. Second best: 3
# Generation 88. Best fitness: 3. Second best: 3
# Generation 89. Best fitness: 3. Second best: 3
# Generation 90. Best fitness: 3. Second best: 3
# Generation 91. Best fitness: 3. Second best: 3
# Generation 92. Best fitness: 3. Second best: 3
# Generation 93. Best fitness: 3. Second best: 3
# Generation 94. Best fitness: 3. Second best: 3
# Generation 95. Best fitness: 3. Second best: 3
# Generation 96. Best fitness: 3. Second best: 3
# Generation 97. Best fitness: 3. Second best: 3
# Generation 98. Best fitness: 3. Second best: 3
# Generation 99. Best fitness: 3. Second best: 3
# Generation 100. Best fitness: 3. Second best: 3
# Generation 101. Best fitness: 3. Second best: 3
# Generation 102. Best fitness: 3. Second best: 3
# Generation 103. Best fitness: 3. Second best: 3
# Generation 104. Best fitness: 3. Second best: 3
# Generation 105. Best fitness: 3. Second best: 3
# Generation 106. Best fitness: 3. Second best: 3
# Generation 107. Best fitness: 3. Second best: 3
# Generation 108. Best fitness: 3. Second best: 3
# Generation 109. Best fitness: 3. Second best: 3
# Generation 110. Best fitness: 2. Second best: 3
# Generation 111. Best fitness: 2. Second best: 2
# Generation 112. Best fitness: 2. Second best: 2
# Generation 113. Best fitness: 2. Second best: 2
# Generation 114. Best fitness: 2. Second best: 2
# Generation 115. Best fitness: 2. Second best: 2
# Generation 116. Best fitness: 2. Second best: 2
# Generation 117. Best fitness: 2. Second best: 2
# Generation 118. Best fitness: 2. Second best: 2
# Generation 119. Best fitness: 2. Second best: 2
# Generation 120. Best fitness: 2. Second best: 2
# Generation 121. Best fitness: 2. Second best: 2
# Generation 122. Best fitness: 2. Second best: 2
# Generation 123. Best fitness: 2. Second best: 2
# Generation 124. Best fitness: 2. Second best: 2
# Generation 125. Best fitness: 2. Second best: 2
# Generation 126. Best fitness: 2. Second best: 2
# Generation 127. Best fitness: 2. Second best: 2
# Generation 128. Best fitness: 2. Second best: 2
# Generation 129. Best fitness: 2. Second best: 2
# Generation 130. Best fitness: 2. Second best: 2
# Generation 131. Best fitness: 2. Second best: 2
# Generation 132. Best fitness: 2. Second best: 2
# Generation 133. Best fitness: 2. Second best: 2
# Generation 134. Best fitness: 2. Second best: 2
# Generation 135. Best fitness: 2. Second best: 2
# Generation 136. Best fitness: 2. Second best: 2
# Generation 137. Best fitness: 2. Second best: 2
# Generation 138. Best fitness: 2. Second best: 2
# Generation 139. Best fitness: 2. Second best: 2
# Generation 140. Best fitness: 2. Second best: 2
# Generation 141. Best fitness: 2. Second best: 2
# Generation 142. Best fitness: 2. Second best: 2
# Generation 143. Best fitness: 2. Second best: 2
# Generation 144. Best fitness: 2. Second best: 2
# Generation 145. Best fitness: 2. Second best: 2
# Generation 146. Best fitness: 2. Second best: 2
# Generation 147. Best fitness: 2. Second best: 2
# Generation 148. Best fitness: 2. Second best: 2
# Generation 149. Best fitness: 2. Second best: 2
# Generation 150. Best fitness: 2. Second best: 2
# Generation 151. Best fitness: 2. Second best: 2
# Generation 152. Best fitness: 2. Second best: 2
# Generation 153. Best fitness: 2. Second best: 2
# Generation 154. Best fitness: 2. Second best: 2
# Generation 155. Best fitness: 2. Second best: 2
# Generation 156. Best fitness: 2. Second best: 2
# Generation 157. Best fitness: 2. Second best: 2
# Generation 158. Best fitness: 2. Second best: 2
# Generation 159. Best fitness: 2. Second best: 2
# Generation 160. Best fitness: 2. Second best: 2
# Generation 161. Best fitness: 2. Second best: 2
# Generation 162. Best fitness: 2. Second best: 2
# Generation 163. Best fitness: 2. Second best: 2
# Generation 164. Best fitness: 2. Second best: 2
# Generation 165. Best fitness: 2. Second best: 2
# Generation 166. Best fitness: 2. Second best: 2
# Generation 167. Best fitness: 2. Second best: 2
# Generation 168. Best fitness: 2. Second best: 2
# Generation 169. Best fitness: 2. Second best: 2
# Generation 170. Best fitness: 2. Second best: 2
# Generation 171. Best fitness: 2. Second best: 2
# Generation 172. Best fitness: 2. Second best: 2
# Generation 173. Best fitness: 2. Second best: 2
# Generation 174. Best fitness: 2. Second best: 2
# Generation 175. Best fitness: 2. Second best: 2
# Generation 176. Best fitness: 2. Second best: 2
# Generation 177. Best fitness: 2. Second best: 2
# Generation 178. Best fitness: 2. Second best: 2
# Generation 179. Best fitness: 2. Second best: 2
# Generation 180. Best fitness: 2. Second best: 2
# Generation 181. Best fitness: 2. Second best: 2
# Generation 182. Best fitness: 2. Second best: 2
# Generation 183. Best fitness: 2. Second best: 2
# Generation 184. Best fitness: 2. Second best: 2
# Generation 185. Best fitness: 2. Second best: 2
# Generation 186. Best fitness: 2. Second best: 2
# Generation 187. Best fitness: 2. Second best: 2
# Generation 188. Best fitness: 2. Second best: 2
# Generation 189. Best fitness: 2. Second best: 2
# Generation 190. Best fitness: 2. Second best: 2
# Generation 191. Best fitness: 2. Second best: 2
# Generation 192. Best fitness: 2. Second best: 2
# Generation 193. Best fitness: 2. Second best: 2
# Generation 194. Best fitness: 2. Second best: 2
# Generation 195. Best fitness: 2. Second best: 2
# Generation 196. Best fitness: 2. Second best: 2
# Generation 197. Best fitness: 2. Second best: 2
# Generation 198. Best fitness: 2. Second best: 2
# Generation 199. Best fitness: 2. Second best: 2
# Generation 200. Best fitness: 2. Second best: 2
# Generation 201. Best fitness: 2. Second best: 2
# Generation 202. Best fitness: 2. Second best: 2
# Generation 203. Best fitness: 2. Second best: 2
# Generation 204. Best fitness: 2. Second best: 2
# Generation 205. Best fitness: 2. Second best: 2
# Generation 206. Best fitness: 2. Second best: 2
# Generation 207. Best fitness: 2. Second best: 2
# Generation 208. Best fitness: 2. Second best: 2
# Generation 209. Best fitness: 2. Second best: 2
# The population has gone stale. Re-seeding...
# 8 4 6 3 5 9 1 2 7
# 9 1 7 6 8 2 3 4 5
# 9 5 3 1 7 4 8 2 6
# 7 9 4 8 2 1 6 3 5
# 6 3 8 7 4 1 5 9 2
# 1 2 9 5 6 3 4 7 8
# 5 8 1 2 4 3 7 6 9
# 2 3 8 7 9 6 5 1 4
# 6 7 9 4 1 3 2 8 5
#
# Initial fitness: 14
# Generation 211. Best fitness: 8. Second best: 8
# Generation 212. Best fitness: 8. Second best: 8
# Generation 213. Best fitness: 7. Second best: 8
# Generation 214. Best fitness: 7. Second best: 8
# Generation 215. Best fitness: 7. Second best: 8
# Generation 216. Best fitness: 7. Second best: 8
# Generation 217. Best fitness: 7. Second best: 7
# Generation 218. Best fitness: 7. Second best: 7
# Generation 219. Best fitness: 7. Second best: 7
# Generation 220. Best fitness: 7. Second best: 7
# Generation 221. Best fitness: 7. Second best: 7
# Generation 222. Best fitness: 7. Second best: 7
# Generation 223. Best fitness: 7. Second best: 7
# Generation 224. Best fitness: 7. Second best: 7
# Generation 225. Best fitness: 7. Second best: 7
# Generation 226. Best fitness: 7. Second best: 7
# Generation 227. Best fitness: 7. Second best: 7
# Generation 228. Best fitness: 7. Second best: 7
# Generation 229. Best fitness: 7. Second best: 7
# Generation 230. Best fitness: 7. Second best: 7
# Generation 231. Best fitness: 7. Second best: 7
# Generation 232. Best fitness: 7. Second best: 7
# Generation 233. Best fitness: 7. Second best: 7
# Generation 234. Best fitness: 5. Second best: 7
# Generation 235. Best fitness: 5. Second best: 7
# Generation 236. Best fitness: 5. Second best: 6
# Generation 237. Best fitness: 5. Second best: 5
# Generation 238. Best fitness: 5. Second best: 5
# Generation 239. Best fitness: 5. Second best: 5
# Generation 240. Best fitness: 5. Second best: 5
# Generation 241. Best fitness: 5. Second best: 5
# Generation 242. Best fitness: 5. Second best: 5
# Generation 243. Best fitness: 5. Second best: 5
# Generation 244. Best fitness: 5. Second best: 5
# Generation 245. Best fitness: 5. Second best: 5
# Generation 246. Best fitness: 5. Second best: 5
# Generation 247. Best fitness: 5. Second best: 5
# Generation 248. Best fitness: 5. Second best: 5
# Generation 249. Best fitness: 5. Second best: 5
# Generation 250. Best fitness: 5. Second best: 5
# Generation 251. Best fitness: 5. Second best: 5
# Generation 252. Best fitness: 5. Second best: 5
# Generation 253. Best fitness: 5. Second best: 5
# Generation 254. Best fitness: 5. Second best: 5
# Generation 255. Best fitness: 5. Second best: 5
# Generation 256. Best fitness: 5. Second best: 5
# Generation 257. Best fitness: 5. Second best: 5
# Generation 258. Best fitness: 5. Second best: 5
# Generation 259. Best fitness: 5. Second best: 5
# Generation 260. Best fitness: 5. Second best: 5
# Generation 261. Best fitness: 5. Second best: 5
# Generation 262. Best fitness: 5. Second best: 5
# Generation 263. Best fitness: 5. Second best: 5
# Generation 264. Best fitness: 5. Second best: 5
# Generation 265. Best fitness: 5. Second best: 5
# Generation 266. Best fitness: 5. Second best: 5
# Generation 267. Best fitness: 5. Second best: 5
# Generation 268. Best fitness: 5. Second best: 5
# Generation 269. Best fitness: 5. Second best: 5
# Generation 270. Best fitness: 5. Second best: 5
# Generation 271. Best fitness: 4. Second best: 5
# Generation 272. Best fitness: 4. Second best: 5
# Generation 273. Best fitness: 4. Second best: 5
# Generation 274. Best fitness: 4. Second best: 4
# Generation 275. Best fitness: 4. Second best: 4
# Generation 276. Best fitness: 4. Second best: 4
# Generation 277. Best fitness: 4. Second best: 4
# Generation 278. Best fitness: 4. Second best: 4
# Generation 279. Best fitness: 4. Second best: 4
# Generation 280. Best fitness: 4. Second best: 4
# Generation 281. Best fitness: 4. Second best: 4
# Generation 282. Best fitness: 4. Second best: 4
# Generation 283. Best fitness: 4. Second best: 4
# Generation 284. Best fitness: 4. Second best: 4
# Generation 285. Best fitness: 4. Second best: 4
# Generation 286. Best fitness: 4. Second best: 4
# Generation 287. Best fitness: 4. Second best: 4
# Generation 288. Best fitness: 4. Second best: 4
# Generation 289. Best fitness: 4. Second best: 4
# Generation 290. Best fitness: 4. Second best: 4
# Generation 291. Best fitness: 4. Second best: 4
# Generation 292. Best fitness: 4. Second best: 4
# Generation 293. Best fitness: 4. Second best: 4
# Generation 294. Best fitness: 4. Second best: 4
# Generation 295. Best fitness: 4. Second best: 4
# Generation 296. Best fitness: 4. Second best: 4
# Generation 297. Best fitness: 4. Second best: 4
# Generation 298. Best fitness: 4. Second best: 4
# Generation 299. Best fitness: 4. Second best: 4
# Generation 300. Best fitness: 4. Second best: 4
# Generation 301. Best fitness: 4. Second best: 4
# Generation 302. Best fitness: 4. Second best: 4
# Generation 303. Best fitness: 4. Second best: 4
# Generation 304. Best fitness: 4. Second best: 4
# Generation 305. Best fitness: 4. Second best: 4
# Generation 306. Best fitness: 4. Second best: 4
# Generation 307. Best fitness: 4. Second best: 4
# Generation 308. Best fitness: 4. Second best: 4
# Generation 309. Best fitness: 4. Second best: 4
# Generation 310. Best fitness: 4. Second best: 4
# Generation 311. Best fitness: 4. Second best: 4
# Generation 312. Best fitness: 4. Second best: 4
# Generation 313. Best fitness: 4. Second best: 4
# Generation 314. Best fitness: 4. Second best: 4
# Generation 315. Best fitness: 4. Second best: 4
# Generation 316. Best fitness: 4. Second best: 4
# Generation 317. Best fitness: 4. Second best: 4
# Generation 318. Best fitness: 4. Second best: 4
# Generation 319. Best fitness: 3. Second best: 4
# Generation 320. Best fitness: 3. Second best: 4
# Generation 321. Best fitness: 3. Second best: 4
# Generation 322. Best fitness: 3. Second best: 4
# Generation 323. Best fitness: 3. Second best: 4
# Generation 324. Best fitness: 3. Second best: 4
# Generation 325. Best fitness: 3. Second best: 4
# Generation 326. Best fitness: 3. Second best: 3
# Generation 327. Best fitness: 3. Second best: 3
# Generation 328. Best fitness: 3. Second best: 3
# Generation 329. Best fitness: 3. Second best: 3
# Generation 330. Best fitness: 3. Second best: 3
# Generation 331. Best fitness: 3. Second best: 3
# Generation 332. Best fitness: 3. Second best: 3
# Generation 333. Best fitness: 3. Second best: 3
# Generation 334. Best fitness: 3. Second best: 3
# Generation 335. Best fitness: 3. Second best: 3
# Generation 336. Best fitness: 3. Second best: 3
# Generation 337. Best fitness: 3. Second best: 3
# Generation 338. Best fitness: 3. Second best: 3
# Generation 339. Best fitness: 3. Second best: 3
# Generation 340. Best fitness: 3. Second best: 3
# Generation 341. Best fitness: 3. Second best: 3
# Generation 342. Best fitness: 3. Second best: 3
# Generation 343. Best fitness: 3. Second best: 3
# Generation 344. Best fitness: 3. Second best: 3
# Generation 345. Best fitness: 3. Second best: 3
# Generation 346. Best fitness: 3. Second best: 3
# Generation 347. Best fitness: 3. Second best: 3
# Generation 348. Best fitness: 3. Second best: 3
# Generation 349. Best fitness: 3. Second best: 3
# Generation 350. Best fitness: 3. Second best: 3
# Generation 351. Best fitness: 3. Second best: 3
# Generation 352. Best fitness: 3. Second best: 3
# Generation 353. Best fitness: 3. Second best: 3
# Generation 354. Best fitness: 3. Second best: 3
# Generation 355. Best fitness: 3. Second best: 3
# Generation 356. Best fitness: 3. Second best: 3
# Generation 357. Best fitness: 3. Second best: 3
# Generation 358. Best fitness: 3. Second best: 3
# Generation 359. Best fitness: 3. Second best: 3
# Generation 360. Best fitness: 3. Second best: 3
# Generation 361. Best fitness: 3. Second best: 3
# Generation 362. Best fitness: 3. Second best: 3
# Generation 363. Best fitness: 3. Second best: 3
# Generation 364. Best fitness: 3. Second best: 3
# Generation 365. Best fitness: 3. Second best: 3
# Generation 366. Best fitness: 3. Second best: 3
# Generation 367. Best fitness: 3. Second best: 3
# Generation 368. Best fitness: 3. Second best: 3
# Generation 369. Best fitness: 3. Second best: 3
# Generation 370. Best fitness: 3. Second best: 3
# Generation 371. Best fitness: 3. Second best: 3
# Generation 372. Best fitness: 3. Second best: 3
# Generation 373. Best fitness: 3. Second best: 3
# Generation 374. Best fitness: 3. Second best: 3
# Generation 375. Best fitness: 3. Second best: 3
# Generation 376. Best fitness: 3. Second best: 3
# Generation 377. Best fitness: 3. Second best: 3
# Generation 378. Best fitness: 3. Second best: 3
# Generation 379. Best fitness: 3. Second best: 3
# Generation 380. Best fitness: 3. Second best: 3
# Generation 381. Best fitness: 3. Second best: 3
# Generation 382. Best fitness: 3. Second best: 3
# Generation 383. Best fitness: 3. Second best: 3
# Generation 384. Best fitness: 3. Second best: 3
# Generation 385. Best fitness: 3. Second best: 3
# Generation 386. Best fitness: 3. Second best: 3
# Generation 387. Best fitness: 3. Second best: 3
# Generation 388. Best fitness: 3. Second best: 3
# Generation 389. Best fitness: 3. Second best: 3
# Generation 390. Best fitness: 3. Second best: 3
# Generation 391. Best fitness: 3. Second best: 3
# Generation 392. Best fitness: 3. Second best: 3
# Generation 393. Best fitness: 3. Second best: 3
# Generation 394. Best fitness: 3. Second best: 3
# Generation 395. Best fitness: 3. Second best: 3
# Generation 396. Best fitness: 3. Second best: 3
# Generation 397. Best fitness: 3. Second best: 3
# Generation 398. Best fitness: 3. Second best: 3
# Generation 399. Best fitness: 3. Second best: 3
# Generation 400. Best fitness: 3. Second best: 3
# Generation 401. Best fitness: 3. Second best: 3
# Generation 402. Best fitness: 3. Second best: 3
# Generation 403. Best fitness: 3. Second best: 3
# Generation 404. Best fitness: 3. Second best: 3
# Generation 405. Best fitness: 3. Second best: 3
# Generation 406. Best fitness: 3. Second best: 3
# Generation 407. Best fitness: 3. Second best: 3
# Generation 408. Best fitness: 3. Second best: 3
# Generation 409. Best fitness: 3. Second best: 3
# Generation 410. Best fitness: 3. Second best: 3
# Generation 411. Best fitness: 3. Second best: 3
# Generation 412. Best fitness: 3. Second best: 3
# Generation 413. Best fitness: 3. Second best: 3
# Generation 414. Best fitness: 3. Second best: 3
# Generation 415. Best fitness: 3. Second best: 3
# Generation 416. Best fitness: 3. Second best: 3
# Generation 417. Best fitness: 3. Second best: 3
# Generation 418. Best fitness: 3. Second best: 3
# Generation 419. Best fitness: 3. Second best: 3
# Generation 420. Best fitness: 3. Second best: 3
# Generation 421. Best fitness: 3. Second best: 3
# Generation 422. Best fitness: 3. Second best: 3
# Generation 423. Best fitness: 3. Second best: 3
# Generation 424. Best fitness: 3. Second best: 3
# The population has gone stale. Re-seeding...
# 8 2 6 3 5 9 1 4 7
# 9 1 7 6 8 2 5 4 3
# 9 5 3 1 7 4 8 2 6
# 7 9 4 8 2 1 6 3 5
# 6 8 5 4 7 3 2 9 1
# 1 6 9 5 3 7 4 2 8
# 6 8 1 2 4 3 7 5 9
# 2 3 8 7 9 6 5 1 4
# 6 7 9 4 1 5 2 8 3
#
# Initial fitness: 13
# Generation 426. Best fitness: 9. Second best: 9
# Generation 427. Best fitness: 8. Second best: 9
# Generation 428. Best fitness: 8. Second best: 8
# Generation 429. Best fitness: 8. Second best: 8
# Generation 430. Best fitness: 8. Second best: 8
# Generation 431. Best fitness: 8. Second best: 8
# Generation 432. Best fitness: 8. Second best: 8
# Generation 433. Best fitness: 8. Second best: 8
# Generation 434. Best fitness: 8. Second best: 8
# Generation 435. Best fitness: 7. Second best: 7
# Generation 436. Best fitness: 7. Second best: 7
# Generation 437. Best fitness: 5. Second best: 7
# Generation 438. Best fitness: 5. Second best: 7
# Generation 439. Best fitness: 5. Second best: 6
# Generation 440. Best fitness: 5. Second best: 6
# Generation 441. Best fitness: 5. Second best: 6
# Generation 442. Best fitness: 5. Second best: 6
# Generation 443. Best fitness: 5. Second best: 6
# Generation 444. Best fitness: 5. Second best: 6
# Generation 445. Best fitness: 5. Second best: 6
# Generation 446. Best fitness: 5. Second best: 5
# Generation 447. Best fitness: 5. Second best: 5
# Generation 448. Best fitness: 5. Second best: 5
# Generation 449. Best fitness: 5. Second best: 5
# Generation 450. Best fitness: 5. Second best: 5
# Generation 451. Best fitness: 5. Second best: 5
# Generation 452. Best fitness: 5. Second best: 5
# Generation 453. Best fitness: 5. Second best: 5
# Generation 454. Best fitness: 5. Second best: 5
# Generation 455. Best fitness: 5. Second best: 5
# Generation 456. Best fitness: 5. Second best: 5
# Generation 457. Best fitness: 5. Second best: 5
# Generation 458. Best fitness: 5. Second best: 5
# Generation 459. Best fitness: 5. Second best: 5
# Generation 460. Best fitness: 5. Second best: 5
# Generation 461. Best fitness: 5. Second best: 5
# Generation 462. Best fitness: 5. Second best: 5
# Generation 463. Best fitness: 5. Second best: 5
# Generation 464. Best fitness: 5. Second best: 5
# Generation 465. Best fitness: 5. Second best: 5
# Generation 466. Best fitness: 5. Second best: 5
# Generation 467. Best fitness: 5. Second best: 5
# Generation 468. Best fitness: 5. Second best: 5
# Generation 469. Best fitness: 5. Second best: 5
# Generation 470. Best fitness: 5. Second best: 5
# Generation 471. Best fitness: 5. Second best: 5
# Generation 472. Best fitness: 5. Second best: 5
# Generation 473. Best fitness: 5. Second best: 5
# Generation 474. Best fitness: 5. Second best: 5
# Generation 475. Best fitness: 5. Second best: 5
# Generation 476. Best fitness: 5. Second best: 5
# Generation 477. Best fitness: 5. Second best: 5
# Generation 478. Best fitness: 5. Second best: 5
# Generation 479. Best fitness: 5. Second best: 5
# Generation 480. Best fitness: 5. Second best: 5
# Generation 481. Best fitness: 5. Second best: 5
# Generation 482. Best fitness: 5. Second best: 5
# Generation 483. Best fitness: 5. Second best: 5
# Generation 484. Best fitness: 5. Second best: 5
# Generation 485. Best fitness: 5. Second best: 5
# Generation 486. Best fitness: 5. Second best: 5
# Generation 487. Best fitness: 5. Second best: 5
# Generation 488. Best fitness: 5. Second best: 5
# Generation 489. Best fitness: 5. Second best: 5
# Generation 490. Best fitness: 5. Second best: 5
# Generation 491. Best fitness: 5. Second best: 5
# Generation 492. Best fitness: 5. Second best: 5
# Generation 493. Best fitness: 5. Second best: 5
# Generation 494. Best fitness: 5. Second best: 5
# Generation 495. Best fitness: 5. Second best: 5
# Generation 496. Best fitness: 5. Second best: 5
# Generation 497. Best fitness: 5. Second best: 5
# Generation 498. Best fitness: 5. Second best: 5
# Generation 499. Best fitness: 5. Second best: 5
# Generation 500. Best fitness: 5. Second best: 5
# Generation 501. Best fitness: 5. Second best: 5
# Generation 502. Best fitness: 5. Second best: 5
# Generation 503. Best fitness: 5. Second best: 5
# Generation 504. Best fitness: 5. Second best: 5
# Generation 505. Best fitness: 5. Second best: 5
# Generation 506. Best fitness: 5. Second best: 5
# Generation 507. Best fitness: 5. Second best: 5
# Generation 508. Best fitness: 5. Second best: 5
# Generation 509. Best fitness: 5. Second best: 5
# Generation 510. Best fitness: 5. Second best: 5
# Generation 511. Best fitness: 5. Second best: 5
# Generation 512. Best fitness: 5. Second best: 5
# Generation 513. Best fitness: 5. Second best: 5
# Generation 514. Best fitness: 5. Second best: 5
# Generation 515. Best fitness: 5. Second best: 5
# Generation 516. Best fitness: 5. Second best: 5
# Generation 517. Best fitness: 5. Second best: 5
# Generation 518. Best fitness: 5. Second best: 5
# Generation 519. Best fitness: 5. Second best: 5
# Generation 520. Best fitness: 5. Second best: 5
# Generation 521. Best fitness: 5. Second best: 5
# Generation 522. Best fitness: 5. Second best: 5
# Generation 523. Best fitness: 5. Second best: 5
# Generation 524. Best fitness: 4. Second best: 5
# Generation 525. Best fitness: 4. Second best: 5
# Generation 526. Best fitness: 4. Second best: 5
# Generation 527. Best fitness: 4. Second best: 5
# Generation 528. Best fitness: 4. Second best: 5
# Generation 529. Best fitness: 4. Second best: 5
# Generation 530. Best fitness: 4. Second best: 5
# Generation 531. Best fitness: 4. Second best: 5
# Generation 532. Best fitness: 4. Second best: 5
# Generation 533. Best fitness: 4. Second best: 5
# Generation 534. Best fitness: 4. Second best: 5
# Generation 535. Best fitness: 4. Second best: 4
# Generation 536. Best fitness: 4. Second best: 4
# Generation 537. Best fitness: 4. Second best: 4
# Generation 538. Best fitness: 4. Second best: 4
# Generation 539. Best fitness: 4. Second best: 4
# Generation 540. Best fitness: 4. Second best: 4
# Generation 541. Best fitness: 4. Second best: 4
# Generation 542. Best fitness: 4. Second best: 4
# Generation 543. Best fitness: 4. Second best: 4
# Generation 544. Best fitness: 4. Second best: 4
# Generation 545. Best fitness: 4. Second best: 4
# Generation 546. Best fitness: 4. Second best: 4
# Generation 547. Best fitness: 4. Second best: 4
# Generation 548. Best fitness: 4. Second best: 4
# Generation 549. Best fitness: 4. Second best: 4
# Generation 550. Best fitness: 4. Second best: 4
# Generation 551. Best fitness: 4. Second best: 4
# Generation 552. Best fitness: 4. Second best: 4
# Generation 553. Best fitness: 4. Second best: 4
# Generation 554. Best fitness: 4. Second best: 4
# Generation 555. Best fitness: 4. Second best: 4
# Generation 556. Best fitness: 4. Second best: 4
# Generation 557. Best fitness: 4. Second best: 4
# Generation 558. Best fitness: 4. Second best: 4
# Generation 559. Best fitness: 4. Second best: 4
# Generation 560. Best fitness: 4. Second best: 4
# Generation 561. Best fitness: 4. Second best: 4
# Generation 562. Best fitness: 4. Second best: 4
# Generation 563. Best fitness: 4. Second best: 4
# Generation 564. Best fitness: 4. Second best: 4
# Generation 565. Best fitness: 4. Second best: 4
# Generation 566. Best fitness: 4. Second best: 4
# Generation 567. Best fitness: 4. Second best: 4
# Generation 568. Best fitness: 4. Second best: 4
# Generation 569. Best fitness: 4. Second best: 4
# Generation 570. Best fitness: 4. Second best: 4
# Generation 571. Best fitness: 4. Second best: 4
# Generation 572. Best fitness: 4. Second best: 4
# Generation 573. Best fitness: 4. Second best: 4
# Generation 574. Best fitness: 4. Second best: 4
# Generation 575. Best fitness: 4. Second best: 4
# Generation 576. Best fitness: 4. Second best: 4
# Generation 577. Best fitness: 4. Second best: 4
# Generation 578. Best fitness: 4. Second best: 4
# Generation 579. Best fitness: 4. Second best: 4
# Generation 580. Best fitness: 4. Second best: 4
# Generation 581. Best fitness: 4. Second best: 4
# Generation 582. Best fitness: 4. Second best: 4
# Generation 583. Best fitness: 4. Second best: 4
# Generation 584. Best fitness: 4. Second best: 4
# Generation 585. Best fitness: 4. Second best: 4
# Generation 586. Best fitness: 4. Second best: 4
# Generation 587. Best fitness: 4. Second best: 4
# Generation 588. Best fitness: 4. Second best: 4
# Generation 589. Best fitness: 4. Second best: 4
# Generation 590. Best fitness: 4. Second best: 4
# Generation 591. Best fitness: 4. Second best: 4
# Generation 592. Best fitness: 4. Second best: 4
# Generation 593. Best fitness: 4. Second best: 4
# Generation 594. Best fitness: 4. Second best: 4
# Generation 595. Best fitness: 4. Second best: 4
# Generation 596. Best fitness: 4. Second best: 4
# Generation 597. Best fitness: 4. Second best: 4
# Generation 598. Best fitness: 4. Second best: 4
# Generation 599. Best fitness: 4. Second best: 4
# Generation 600. Best fitness: 4. Second best: 4
# Generation 601. Best fitness: 4. Second best: 4
# Generation 602. Best fitness: 4. Second best: 4
# Generation 603. Best fitness: 4. Second best: 4
# Generation 604. Best fitness: 4. Second best: 4
# Generation 605. Best fitness: 4. Second best: 4
# Generation 606. Best fitness: 4. Second best: 4
# Generation 607. Best fitness: 4. Second best: 4
# Generation 608. Best fitness: 4. Second best: 4
# Generation 609. Best fitness: 4. Second best: 4
# Generation 610. Best fitness: 4. Second best: 4
# Generation 611. Best fitness: 4. Second best: 4
# Generation 612. Best fitness: 4. Second best: 4
# Generation 613. Best fitness: 4. Second best: 4
# Generation 614. Best fitness: 4. Second best: 4
# Generation 615. Best fitness: 4. Second best: 4
# Generation 616. Best fitness: 4. Second best: 4
# Generation 617. Best fitness: 4. Second best: 4
# Generation 618. Best fitness: 4. Second best: 4
# Generation 619. Best fitness: 4. Second best: 4
# Generation 620. Best fitness: 4. Second best: 4
# Generation 621. Best fitness: 4. Second best: 4
# Generation 622. Best fitness: 4. Second best: 4
# Generation 623. Best fitness: 4. Second best: 4
# Generation 624. Best fitness: 4. Second best: 4
# Generation 625. Best fitness: 4. Second best: 4
# Generation 626. Best fitness: 4. Second best: 4
# Generation 627. Best fitness: 4. Second best: 4
# Generation 628. Best fitness: 4. Second best: 4
# Generation 629. Best fitness: 4. Second best: 4
# Generation 630. Best fitness: 4. Second best: 4
# Generation 631. Best fitness: 4. Second best: 4
# Generation 632. Best fitness: 4. Second best: 4
# Generation 633. Best fitness: 4. Second best: 4
# The population has gone stale. Re-seeding...
# 8 2 6 9 3 5 1 4 7
# 4 1 7 6 8 2 9 5 3
# 9 5 3 1 7 4 8 2 6
# 7 9 4 8 2 1 6 3 5
# 6 3 8 4 7 1 2 9 5
# 1 6 8 5 3 9 4 7 2
# 3 4 1 2 8 5 7 6 9
# 2 3 8 7 9 6 5 1 4
# 6 7 9 4 1 3 2 8 5
#
# Initial fitness: 13
# Generation 635. Best fitness: 5. Second best: 7
# Generation 636. Best fitness: 5. Second best: 7
# Generation 637. Best fitness: 5. Second best: 7
# Generation 638. Best fitness: 5. Second best: 5
# Generation 639. Best fitness: 5. Second best: 5
# Generation 640. Best fitness: 5. Second best: 5
# Generation 641. Best fitness: 5. Second best: 5
# Generation 642. Best fitness: 5. Second best: 5
# Generation 643. Best fitness: 5. Second best: 5
# Generation 644. Best fitness: 5. Second best: 5
# Generation 645. Best fitness: 5. Second best: 5
# Generation 646. Best fitness: 5. Second best: 5
# Generation 647. Best fitness: 5. Second best: 5
# Generation 648. Best fitness: 5. Second best: 5
# Generation 649. Best fitness: 5. Second best: 5
# Generation 650. Best fitness: 5. Second best: 5
# Generation 651. Best fitness: 5. Second best: 5
# Generation 652. Best fitness: 5. Second best: 5
# Generation 653. Best fitness: 5. Second best: 5
# Generation 654. Best fitness: 4. Second best: 5
# Generation 655. Best fitness: 4. Second best: 5
# Generation 656. Best fitness: 4. Second best: 4
# Generation 657. Best fitness: 4. Second best: 4
# Generation 658. Best fitness: 4. Second best: 4
# Generation 659. Best fitness: 4. Second best: 4
# Generation 660. Best fitness: 4. Second best: 4
# Generation 661. Best fitness: 4. Second best: 4
# Generation 662. Best fitness: 4. Second best: 4
# Generation 663. Best fitness: 4. Second best: 4
# Generation 664. Best fitness: 4. Second best: 4
# Generation 665. Best fitness: 4. Second best: 4
# Generation 666. Best fitness: 4. Second best: 4
# Generation 667. Best fitness: 4. Second best: 4
# Generation 668. Best fitness: 4. Second best: 4
# Generation 669. Best fitness: 4. Second best: 4
# Generation 670. Best fitness: 4. Second best: 4
# Generation 671. Best fitness: 4. Second best: 4
# Generation 672. Best fitness: 4. Second best: 4
# Generation 673. Best fitness: 4. Second best: 4
# Generation 674. Best fitness: 4. Second best: 4
# Generation 675. Best fitness: 4. Second best: 4
# Generation 676. Best fitness: 4. Second best: 4
# Generation 677. Best fitness: 4. Second best: 4
# Generation 678. Best fitness: 4. Second best: 4
# Generation 679. Best fitness: 4. Second best: 4
# Generation 680. Best fitness: 4. Second best: 4
# Generation 681. Best fitness: 4. Second best: 4
# Generation 682. Best fitness: 4. Second best: 4
# Generation 683. Best fitness: 4. Second best: 4
# Generation 684. Best fitness: 4. Second best: 4
# Generation 685. Best fitness: 4. Second best: 4
# Generation 686. Best fitness: 4. Second best: 4
# Generation 687. Best fitness: 2. Second best: 4
# Generation 688. Best fitness: 2. Second best: 3
# Generation 689. Best fitness: 2. Second best: 2
# Generation 690. Best fitness: 2. Second best: 2
# Generation 691. Best fitness: 2. Second best: 2
# Generation 692. Best fitness: 2. Second best: 2
# Generation 693. Best fitness: 2. Second best: 2
# Generation 694. Best fitness: 2. Second best: 2
# Generation 695. Best fitness: 2. Second best: 2
# Generation 696. Best fitness: 2. Second best: 2
# Generation 697. Best fitness: 2. Second best: 2
# Generation 698. Best fitness: 2. Second best: 2
# Generation 699. Best fitness: 2. Second best: 2
# Generation 700. Best fitness: 2. Second best: 2
# Generation 701. Best fitness: 2. Second best: 2
# Generation 702. Best fitness: 2. Second best: 2
# Generation 703. Best fitness: 2. Second best: 2
# Generation 704. Best fitness: 2. Second best: 2
# Generation 705. Best fitness: 2. Second best: 2
# Generation 706. Best fitness: 2. Second best: 2
# Generation 707. Best fitness: 2. Second best: 2
# Generation 708. Best fitness: 2. Second best: 2
# Generation 709. Best fitness: 2. Second best: 2
# Generation 710. Best fitness: 2. Second best: 2
# Generation 711. Best fitness: 2. Second best: 2
# Generation 712. Best fitness: 2. Second best: 2
# Generation 713. Best fitness: 2. Second best: 2
# Generation 714. Best fitness: 2. Second best: 2
# Generation 715. Best fitness: 2. Second best: 2
# Generation 716. Best fitness: 2. Second best: 2
# Generation 717. Best fitness: 2. Second best: 2
# Generation 718. Best fitness: 2. Second best: 2
# Generation 719. Best fitness: 2. Second best: 2
# Generation 720. Best fitness: 2. Second best: 2
# Generation 721. Best fitness: 2. Second best: 2
# Generation 722. Best fitness: 2. Second best: 2
# Generation 723. Best fitness: 2. Second best: 2
# Generation 724. Best fitness: 2. Second best: 2
# Generation 725. Best fitness: 2. Second best: 2
# Generation 726. Best fitness: 2. Second best: 2
# Generation 727. Best fitness: 2. Second best: 2
# Generation 728. Best fitness: 2. Second best: 2
# Generation 729. Best fitness: 2. Second best: 2
# Generation 730. Best fitness: 2. Second best: 2
# Generation 731. Best fitness: 2. Second best: 2
# Generation 732. Best fitness: 2. Second best: 2
# Generation 733. Best fitness: 2. Second best: 2
# Generation 734. Best fitness: 2. Second best: 2
# Generation 735. Best fitness: 2. Second best: 2
# Generation 736. Best fitness: 2. Second best: 2
# Generation 737. Best fitness: 2. Second best: 2
# Generation 738. Best fitness: 2. Second best: 2
# Generation 739. Best fitness: 2. Second best: 2
# Generation 740. Best fitness: 2. Second best: 2
# Generation 741. Best fitness: 2. Second best: 2
# Generation 742. Best fitness: 2. Second best: 2
# Generation 743. Best fitness: 2. Second best: 2
# Generation 744. Best fitness: 2. Second best: 2
# Generation 745. Best fitness: 2. Second best: 2
# Generation 746. Best fitness: 2. Second best: 2
# Generation 747. Best fitness: 2. Second best: 2
# Generation 748. Best fitness: 2. Second best: 2
# Generation 749. Best fitness: 2. Second best: 2
# Generation 750. Best fitness: 2. Second best: 2
# Generation 751. Best fitness: 2. Second best: 2
# Generation 752. Best fitness: 2. Second best: 2
# Generation 753. Best fitness: 2. Second best: 2
# Generation 754. Best fitness: 2. Second best: 2
# Generation 755. Best fitness: 2. Second best: 2
# Generation 756. Best fitness: 2. Second best: 2
# Generation 757. Best fitness: 2. Second best: 2
# Generation 758. Best fitness: 2. Second best: 2
# Generation 759. Best fitness: 2. Second best: 2
# Generation 760. Best fitness: 2. Second best: 2
# Generation 761. Best fitness: 2. Second best: 2
# Generation 762. Best fitness: 2. Second best: 2
# Generation 763. Best fitness: 2. Second best: 2
# Generation 764. Best fitness: 2. Second best: 2
# Generation 765. Best fitness: 2. Second best: 2
# Generation 766. Best fitness: 2. Second best: 2
# Generation 767. Best fitness: 2. Second best: 2
# Generation 768. Best fitness: 2. Second best: 2
# Generation 769. Best fitness: 2. Second best: 2
# Generation 770. Best fitness: 2. Second best: 2
# Generation 771. Best fitness: 2. Second best: 2
# Generation 772. Best fitness: 2. Second best: 2
# Generation 773. Best fitness: 2. Second best: 2
# Generation 774. Best fitness: 2. Second best: 2
# Generation 775. Best fitness: 2. Second best: 2
# Generation 776. Best fitness: 2. Second best: 2
# Generation 777. Best fitness: 2. Second best: 2
# Generation 778. Best fitness: 2. Second best: 2
# Generation 779. Best fitness: 2. Second best: 2
# Generation 780. Best fitness: 2. Second best: 2
# Generation 781. Best fitness: 2. Second best: 2
# Generation 782. Best fitness: 2. Second best: 2
# Generation 783. Best fitness: 2. Second best: 2
# Generation 784. Best fitness: 2. Second best: 2
# Generation 785. Best fitness: 2. Second best: 2
# Generation 786. Best fitness: 2. Second best: 2
# Generation 787. Best fitness: 2. Second best: 2
# Generation 788. Best fitness: 2. Second best: 2
# Generation 789. Best fitness: 2. Second best: 2
# Generation 790. Best fitness: 2. Second best: 2
# Generation 791. Best fitness: 2. Second best: 2
# Generation 792. Best fitness: 2. Second best: 2
# Generation 793. Best fitness: 2. Second best: 2
# Generation 794. Best fitness: 2. Second best: 2
# Generation 795. Best fitness: 2. Second best: 2
# Generation 796. Best fitness: 2. Second best: 2
# Generation 797. Best fitness: 2. Second best: 2
# Generation 798. Best fitness: 2. Second best: 2
# Generation 799. Best fitness: 2. Second best: 2
# Generation 800. Best fitness: 2. Second best: 2
# Generation 801. Best fitness: 2. Second best: 2
# Generation 802. Best fitness: 2. Second best: 2
# Generation 803. Best fitness: 2. Second best: 2
# Generation 804. Best fitness: 2. Second best: 2
# Generation 805. Best fitness: 2. Second best: 2
# Generation 806. Best fitness: 2. Second best: 2
# Generation 807. Best fitness: 2. Second best: 2
# Generation 808. Best fitness: 2. Second best: 2
# Generation 809. Best fitness: 2. Second best: 2
# Generation 810. Best fitness: 2. Second best: 2
# Generation 811. Best fitness: 2. Second best: 2
# Generation 812. Best fitness: 2. Second best: 2
# Generation 813. Best fitness: 2. Second best: 2
# Generation 814. Best fitness: 2. Second best: 2
# Generation 815. Best fitness: 2. Second best: 2
# Generation 816. Best fitness: 2. Second best: 2
# Generation 817. Best fitness: 2. Second best: 2
# Generation 818. Best fitness: 2. Second best: 2
# Generation 819. Best fitness: 2. Second best: 2
# Generation 820. Best fitness: 2. Second best: 2
# Generation 821. Best fitness: 2. Second best: 2
# Generation 822. Best fitness: 2. Second best: 2
# Generation 823. Best fitness: 2. Second best: 2
# Generation 824. Best fitness: 2. Second best: 2
# Generation 825. Best fitness: 2. Second best: 2
# Generation 826. Best fitness: 2. Second best: 2
# Generation 827. Best fitness: 2. Second best: 2
# Generation 828. Best fitness: 2. Second best: 2
# Generation 829. Best fitness: 2. Second best: 2
# Generation 830. Best fitness: 2. Second best: 2
# Generation 831. Best fitness: 2. Second best: 2
# The population has gone stale. Re-seeding...
# 8 4 6 9 3 5 1 2 7
# 9 1 7 6 8 2 3 5 4
# 9 5 3 1 7 4 8 2 6
# 7 9 4 8 2 1 6 3 5
# 3 6 8 4 7 1 2 9 5
# 1 3 2 5 6 9 4 7 8
# 3 4 1 2 5 8 7 6 9
# 2 4 8 7 9 6 3 1 5
# 6 7 9 4 1 3 2 8 5
#
# Initial fitness: 14
# Generation 833. Best fitness: 8. Second best: 8
# Generation 834. Best fitness: 8. Second best: 8
# Generation 835. Best fitness: 8. Second best: 8
# Generation 836. Best fitness: 8. Second best: 8
# Generation 837. Best fitness: 8. Second best: 8
# Generation 838. Best fitness: 8. Second best: 8
# Generation 839. Best fitness: 7. Second best: 8
# Generation 840. Best fitness: 7. Second best: 7
# Generation 841. Best fitness: 6. Second best: 6
# Generation 842. Best fitness: 6. Second best: 6
# Generation 843. Best fitness: 6. Second best: 6
# Generation 844. Best fitness: 6. Second best: 6
# Generation 845. Best fitness: 6. Second best: 6
# Generation 846. Best fitness: 6. Second best: 6
# Generation 847. Best fitness: 6. Second best: 6
# Generation 848. Best fitness: 6. Second best: 6
# Generation 849. Best fitness: 6. Second best: 6
# Generation 850. Best fitness: 6. Second best: 6
# Generation 851. Best fitness: 6. Second best: 6
# Generation 852. Best fitness: 6. Second best: 6
# Generation 853. Best fitness: 5. Second best: 6
# Generation 854. Best fitness: 5. Second best: 5
# Generation 855. Best fitness: 5. Second best: 5
# Generation 856. Best fitness: 5. Second best: 5
# Generation 857. Best fitness: 5. Second best: 5
# Generation 858. Best fitness: 5. Second best: 5
# Generation 859. Best fitness: 5. Second best: 5
# Generation 860. Best fitness: 5. Second best: 5
# Generation 861. Best fitness: 5. Second best: 5
# Generation 862. Best fitness: 5. Second best: 5
# Generation 863. Best fitness: 5. Second best: 5
# Generation 864. Best fitness: 5. Second best: 5
# Generation 865. Best fitness: 5. Second best: 5
# Generation 866. Best fitness: 5. Second best: 5
# Generation 867. Best fitness: 5. Second best: 5
# Generation 868. Best fitness: 5. Second best: 5
# Generation 869. Best fitness: 5. Second best: 5
# Generation 870. Best fitness: 5. Second best: 5
# Generation 871. Best fitness: 5. Second best: 5
# Generation 872. Best fitness: 5. Second best: 5
# Generation 873. Best fitness: 5. Second best: 5
# Generation 874. Best fitness: 5. Second best: 5
# Generation 875. Best fitness: 5. Second best: 5
# Generation 876. Best fitness: 5. Second best: 5
# Generation 877. Best fitness: 5. Second best: 5
# Generation 878. Best fitness: 5. Second best: 5
# Generation 879. Best fitness: 5. Second best: 5
# Generation 880. Best fitness: 5. Second best: 5
# Generation 881. Best fitness: 5. Second best: 5
# Generation 882. Best fitness: 5. Second best: 5
# Generation 883. Best fitness: 5. Second best: 5
# Generation 884. Best fitness: 5. Second best: 5
# Generation 885. Best fitness: 5. Second best: 5
# Generation 886. Best fitness: 5. Second best: 5
# Generation 887. Best fitness: 5. Second best: 5
# Generation 888. Best fitness: 5. Second best: 5
# Generation 889. Best fitness: 5. Second best: 5
# Generation 890. Best fitness: 5. Second best: 5
# Generation 891. Best fitness: 5. Second best: 5
# Generation 892. Best fitness: 5. Second best: 5
# Generation 893. Best fitness: 5. Second best: 5
# Generation 894. Best fitness: 5. Second best: 5
# Generation 895. Best fitness: 5. Second best: 5
# Generation 896. Best fitness: 5. Second best: 5
# Generation 897. Best fitness: 5. Second best: 5
# Generation 898. Best fitness: 5. Second best: 5
# Generation 899. Best fitness: 5. Second best: 5
# Generation 900. Best fitness: 5. Second best: 5
# Generation 901. Best fitness: 5. Second best: 5
# Generation 902. Best fitness: 5. Second best: 5
# Generation 903. Best fitness: 5. Second best: 5
# Generation 904. Best fitness: 5. Second best: 5
# Generation 905. Best fitness: 5. Second best: 5
# Generation 906. Best fitness: 5. Second best: 5
# Generation 907. Best fitness: 5. Second best: 5
# Generation 908. Best fitness: 5. Second best: 5
# Generation 909. Best fitness: 5. Second best: 5
# Generation 910. Best fitness: 5. Second best: 5
# Generation 911. Best fitness: 5. Second best: 5
# Generation 912. Best fitness: 5. Second best: 5
# Generation 913. Best fitness: 5. Second best: 5
# Generation 914. Best fitness: 5. Second best: 5
# Generation 915. Best fitness: 5. Second best: 5
# Generation 916. Best fitness: 5. Second best: 5
# Generation 917. Best fitness: 5. Second best: 5
# Generation 918. Best fitness: 5. Second best: 5
# Generation 919. Best fitness: 5. Second best: 5
# Generation 920. Best fitness: 5. Second best: 5
# Generation 921. Best fitness: 5. Second best: 5
# Generation 922. Best fitness: 5. Second best: 5
# Generation 923. Best fitness: 5. Second best: 5
# Generation 924. Best fitness: 4. Second best: 5
# Generation 925. Best fitness: 4. Second best: 5
# Generation 926. Best fitness: 4. Second best: 5
# Generation 927. Best fitness: 4. Second best: 4
# Generation 928. Best fitness: 4. Second best: 4
# Generation 929. Best fitness: 4. Second best: 4
# Generation 930. Best fitness: 4. Second best: 4
# Generation 931. Best fitness: 4. Second best: 4
# Generation 932. Best fitness: 4. Second best: 4
# Generation 933. Best fitness: 4. Second best: 4
# Generation 934. Best fitness: 4. Second best: 4
# Generation 935. Best fitness: 4. Second best: 4
# Generation 936. Best fitness: 4. Second best: 4
# Generation 937. Best fitness: 4. Second best: 4
# Generation 938. Best fitness: 4. Second best: 4
# Generation 939. Best fitness: 4. Second best: 4
# Generation 940. Best fitness: 4. Second best: 4
# Generation 941. Best fitness: 4. Second best: 4
# Generation 942. Best fitness: 4. Second best: 4
# Generation 943. Best fitness: 4. Second best: 4
# Generation 944. Best fitness: 4. Second best: 4
# Generation 945. Best fitness: 4. Second best: 4
# Generation 946. Best fitness: 4. Second best: 4
# Generation 947. Best fitness: 4. Second best: 4
# Generation 948. Best fitness: 4. Second best: 4
# Generation 949. Best fitness: 4. Second best: 4
# Generation 950. Best fitness: 4. Second best: 4
# Generation 951. Best fitness: 4. Second best: 4
# Generation 952. Best fitness: 4. Second best: 4
# Generation 953. Best fitness: 4. Second best: 4
# Generation 954. Best fitness: 4. Second best: 4
# Generation 955. Best fitness: 4. Second best: 4
# Generation 956. Best fitness: 4. Second best: 4
# Generation 957. Best fitness: 4. Second best: 4
# Generation 958. Best fitness: 4. Second best: 4
# Generation 959. Best fitness: 4. Second best: 4
# Generation 960. Best fitness: 4. Second best: 4
# Generation 961. Best fitness: 4. Second best: 4
# Generation 962. Best fitness: 4. Second best: 4
# Generation 963. Best fitness: 4. Second best: 4
# Generation 964. Best fitness: 4. Second best: 4
# Generation 965. Best fitness: 4. Second best: 4
# Generation 966. Best fitness: 4. Second best: 4
# Generation 967. Best fitness: 4. Second best: 4
# Generation 968. Best fitness: 4. Second best: 4
# Generation 969. Best fitness: 4. Second best: 4
# Generation 970. Best fitness: 4. Second best: 4
# Generation 971. Best fitness: 4. Second best: 4
# Generation 972. Best fitness: 4. Second best: 4
# Generation 973. Best fitness: 4. Second best: 4
# Generation 974. Best fitness: 4. Second best: 4
# Generation 975. Best fitness: 4. Second best: 4
# Generation 976. Best fitness: 4. Second best: 4
# Generation 977. Best fitness: 4. Second best: 4
# Generation 978. Best fitness: 4. Second best: 4
# Generation 979. Best fitness: 4. Second best: 4
# Generation 980. Best fitness: 4. Second best: 4
# Generation 981. Best fitness: 4. Second best: 4
# ...
# Generation 1284. Best fitness: 4. Second best: 4
# Generation 1285. Best fitness: 4. Second best: 4
# Generation 1286. Best fitness: 3. Second best: 4
# Generation 1287. Best fitness: 3. Second best: 4
# Generation 1288. Best fitness: 3. Second best: 4
# Generation 1289. Best fitness: 3. Second best: 4
# Generation 1290. Best fitness: 3. Second best: 3
# Generation 1291. Best fitness: 3. Second best: 3
# Generation 1292. Best fitness: 3. Second best: 3
# Generation 1293. Best fitness: 3. Second best: 3
# Generation 1294. Best fitness: 3. Second best: 3
# Generation 1295. Best fitness: 3. Second best: 3
# Generation 1296. Best fitness: 3. Second best: 3
# Generation 1297. Best fitness: 3. Second best: 3
# Generation 1298. Best fitness: 3. Second best: 3
# Generation 1299. Best fitness: 3. Second best: 3
# Generation 1300. Best fitness: 3. Second best: 3
# Generation 1301. Best fitness: 3. Second best: 3
# Generation 1302. Best fitness: 3. Second best: 3
# Generation 1303. Best fitness: 3. Second best: 3
# Generation 1304. Best fitness: 3. Second best: 3
# Generation 1305. Best fitness: 3. Second best: 3
# Generation 1306. Best fitness: 3. Second best: 3
# Generation 1307. Best fitness: 3. Second best: 3
# Generation 1308. Best fitness: 3. Second best: 3
# Generation 1309. Best fitness: 3. Second best: 3
# Generation 1310. Best fitness: 3. Second best: 3
# Generation 1311. Best fitness: 3. Second best: 3
# Generation 1312. Best fitness: 3. Second best: 3
# Generation 1313. Best fitness: 3. Second best: 3
# Generation 1314. Best fitness: 3. Second best: 3
# Generation 1315. Best fitness: 3. Second best: 3
# Generation 1316. Best fitness: 3. Second best: 3
# Generation 1317. Best fitness: 3. Second best: 3
# Generation 1318. Best fitness: 3. Second best: 3
# Generation 1319. Best fitness: 3. Second best: 3
# Generation 1320. Best fitness: 3. Second best: 3
# Generation 1321. Best fitness: 3. Second best: 3
# Generation 1322. Best fitness: 3. Second best: 3
# Generation 1323. Best fitness: 3. Second best: 3
# Generation 1324. Best fitness: 3. Second best: 3
# Generation 1325. Best fitness: 3. Second best: 3
# Generation 1326. Best fitness: 3. Second best: 3
# Generation 1327. Best fitness: 3. Second best: 3
# Generation 1328. Best fitness: 3. Second best: 3
# Generation 1329. Best fitness: 3. Second best: 3
# Generation 1330. Best fitness: 3. Second best: 3
# Generation 1331. Best fitness: 3. Second best: 3
# Generation 1332. Best fitness: 3. Second best: 3
# Generation 1333. Best fitness: 3. Second best: 3
# Generation 1334. Best fitness: 3. Second best: 3
# Generation 1335. Best fitness: 3. Second best: 3
# Generation 1336. Best fitness: 3. Second best: 3
# Generation 1337. Best fitness: 3. Second best: 3
# Generation 1338. Best fitness: 3. Second best: 3
# Generation 1339. Best fitness: 3. Second best: 3
# Generation 1340. Best fitness: 3. Second best: 3
# Generation 1341. Best fitness: 3. Second best: 3
# Generation 1342. Best fitness: 3. Second best: 3
# Generation 1343. Best fitness: 3. Second best: 3
# Generation 1344. Best fitness: 3. Second best: 3
# Generation 1345. Best fitness: 3. Second best: 3
# Generation 1346. Best fitness: 3. Second best: 3
# Generation 1347. Best fitness: 3. Second best: 3
# Generation 1348. Best fitness: 3. Second best: 3
# Generation 1349. Best fitness: 3. Second best: 3
# Generation 1350. Best fitness: 3. Second best: 3
# Generation 1351. Best fitness: 3. Second best: 3
# Generation 1352. Best fitness: 3. Second best: 3
# Generation 1353. Best fitness: 3. Second best: 3
# Generation 1354. Best fitness: 3. Second best: 3
# Generation 1355. Best fitness: 3. Second best: 3
# Generation 1356. Best fitness: 3. Second best: 3
# Generation 1357. Best fitness: 3. Second best: 3
# Generation 1358. Best fitness: 3. Second best: 3
# Generation 1359. Best fitness: 3. Second best: 3
# Generation 1360. Best fitness: 3. Second best: 3
# Generation 1361. Best fitness: 3. Second best: 3
# Generation 1362. Best fitness: 3. Second best: 3
# Generation 1363. Best fitness: 3. Second best: 3
# Generation 1364. Best fitness: 3. Second best: 3
# Generation 1365. Best fitness: 3. Second best: 3
# Generation 1366. Best fitness: 3. Second best: 3
# Generation 1367. Best fitness: 3. Second best: 3
# Generation 1368. Best fitness: 3. Second best: 3
# Generation 1369. Best fitness: 3. Second best: 3
# Generation 1370. Best fitness: 3. Second best: 3
# Generation 1371. Best fitness: 3. Second best: 3
# Generation 1372. Best fitness: 3. Second best: 3
# Generation 1373. Best fitness: 3. Second best: 3
# Generation 1374. Best fitness: 3. Second best: 3
# Generation 1375. Best fitness: 3. Second best: 3
# Generation 1376. Best fitness: 3. Second best: 3
# Generation 1377. Best fitness: 3. Second best: 3
# Generation 1378. Best fitness: 3. Second best: 3
# Generation 1379. Best fitness: 3. Second best: 3
# Generation 1380. Best fitness: 3. Second best: 3
# Generation 1381. Best fitness: 3. Second best: 3
# Generation 1382. Best fitness: 3. Second best: 3
# Generation 1383. Best fitness: 3. Second best: 3
# Generation 1384. Best fitness: 3. Second best: 3
# Generation 1385. Best fitness: 3. Second best: 3
# Generation 1386. Best fitness: 3. Second best: 3
# Generation 1387. Best fitness: 3. Second best: 3
# Generation 1388. Best fitness: 3. Second best: 3
# Generation 1389. Best fitness: 3. Second best: 3
# Generation 1390. Best fitness: 3. Second best: 3
# Generation 1391. Best fitness: 3. Second best: 3
# Generation 1392. Best fitness: 3. Second best: 3
# Generation 1393. Best fitness: 3. Second best: 3
# Generation 1394. Best fitness: 3. Second best: 3
# Generation 1395. Best fitness: 3. Second best: 3
# Generation 1396. Best fitness: 3. Second best: 3
# Generation 1397. Best fitness: 3. Second best: 3
# Generation 1398. Best fitness: 3. Second best: 3
# Generation 1399. Best fitness: 3. Second best: 3
# Generation 1400. Best fitness: 3. Second best: 3
# Generation 1401. Best fitness: 3. Second best: 3
# Generation 1402. Best fitness: 3. Second best: 3
# Generation 1403. Best fitness: 3. Second best: 3
# Generation 1404. Best fitness: 3. Second best: 3
# The population has gone stale. Re-seeding...
# 8 2 6 9 3 5 1 4 7
# 9 1 7 6 8 2 3 5 4
# 9 5 3 1 7 4 8 2 6
# 7 9 4 8 2 1 6 3 5
# 3 6 8 4 7 1 2 9 5
# 1 3 9 5 6 7 4 2 8
# 5 4 1 2 3 8 7 6 9
# 2 4 8 7 9 6 3 1 5
# 6 7 9 4 1 3 5 8 2
#
# Initial fitness: 12
# Generation 1406. Best fitness: 5. Second best: 7
# Generation 1407. Best fitness: 5. Second best: 5
# Generation 1408. Best fitness: 5. Second best: 5
# Generation 1409. Best fitness: 5. Second best: 5
# Generation 1410. Best fitness: 5. Second best: 5
# Generation 1411. Best fitness: 5. Second best: 5
# Generation 1412. Best fitness: 5. Second best: 5
# Generation 1413. Best fitness: 5. Second best: 5
# Generation 1414. Best fitness: 5. Second best: 5
# Generation 1415. Best fitness: 5. Second best: 5
# Generation 1416. Best fitness: 5. Second best: 5
# Generation 1417. Best fitness: 5. Second best: 5
# Generation 1418. Best fitness: 5. Second best: 5
# Generation 1419. Best fitness: 5. Second best: 5
# Generation 1420. Best fitness: 5. Second best: 5
# Generation 1421. Best fitness: 4. Second best: 5
# Generation 1422. Best fitness: 4. Second best: 5
# Generation 1423. Best fitness: 4. Second best: 5
# Generation 1424. Best fitness: 4. Second best: 5
# Generation 1425. Best fitness: 4. Second best: 5
# Generation 1426. Best fitness: 4. Second best: 5
# Generation 1427. Best fitness: 4. Second best: 5
# Generation 1428. Best fitness: 4. Second best: 5
# Generation 1429. Best fitness: 4. Second best: 5
# Generation 1430. Best fitness: 4. Second best: 4
# Generation 1431. Best fitness: 4. Second best: 4
# Generation 1432. Best fitness: 4. Second best: 4
# Generation 1433. Best fitness: 4. Second best: 4
# Generation 1434. Best fitness: 4. Second best: 4
# Generation 1435. Best fitness: 4. Second best: 4
# Generation 1436. Best fitness: 4. Second best: 4
# Generation 1437. Best fitness: 4. Second best: 4
# Generation 1438. Best fitness: 4. Second best: 4
# Generation 1439. Best fitness: 4. Second best: 4
# Generation 1440. Best fitness: 4. Second best: 4
# Generation 1441. Best fitness: 4. Second best: 4
# Generation 1442. Best fitness: 4. Second best: 4
# Generation 1443. Best fitness: 4. Second best: 4
# Generation 1444. Best fitness: 4. Second best: 4
# Generation 1445. Best fitness: 4. Second best: 4
# Generation 1446. Best fitness: 4. Second best: 4
# Generation 1447. Best fitness: 4. Second best: 4
# Generation 1448. Best fitness: 4. Second best: 4
# Generation 1449. Best fitness: 4. Second best: 4
# Generation 1450. Best fitness: 4. Second best: 4
# Generation 1451. Best fitness: 4. Second best: 4
# Generation 1452. Best fitness: 4. Second best: 4
# Generation 1453. Best fitness: 4. Second best: 4
# Generation 1454. Best fitness: 4. Second best: 4
# Generation 1455. Best fitness: 4. Second best: 4
# Generation 1456. Best fitness: 4. Second best: 4
# Generation 1457. Best fitness: 4. Second best: 4
# Generation 1458. Best fitness: 4. Second best: 4
# Generation 1459. Best fitness: 4. Second best: 4
# Generation 1460. Best fitness: 4. Second best: 4
# Generation 1461. Best fitness: 3. Second best: 4
# Generation 1462. Best fitness: 3. Second best: 4
# Generation 1463. Best fitness: 3. Second best: 4
# Generation 1464. Best fitness: 3. Second best: 4
# Generation 1465. Best fitness: 3. Second best: 4
# Generation 1466. Best fitness: 3. Second best: 4
# Generation 1467. Best fitness: 3. Second best: 4
# Generation 1468. Best fitness: 3. Second best: 4
# Generation 1469. Best fitness: 3. Second best: 4
# Generation 1470. Best fitness: 3. Second best: 4
# Generation 1471. Best fitness: 3. Second best: 4
# Generation 1472. Best fitness: 3. Second best: 4
# Generation 1473. Best fitness: 3. Second best: 4
# Generation 1474. Best fitness: 3. Second best: 4
# Generation 1475. Best fitness: 3. Second best: 3
# Generation 1476. Best fitness: 3. Second best: 3
# Generation 1477. Best fitness: 3. Second best: 3
# Generation 1478. Best fitness: 3. Second best: 3
# Generation 1479. Best fitness: 3. Second best: 3
# Generation 1480. Best fitness: 3. Second best: 3
# Generation 1481. Best fitness: 3. Second best: 3
# Generation 1482. Best fitness: 3. Second best: 3
# Generation 1483. Best fitness: 3. Second best: 3
# Generation 1484. Best fitness: 3. Second best: 3
# Generation 1485. Best fitness: 3. Second best: 3
# Generation 1486. Best fitness: 3. Second best: 3
# Generation 1487. Best fitness: 3. Second best: 3
# Generation 1488. Best fitness: 3. Second best: 3
# Generation 1489. Best fitness: 3. Second best: 3
# Generation 1490. Best fitness: 3. Second best: 3
# Generation 1491. Best fitness: 3. Second best: 3
# Generation 1492. Best fitness: 3. Second best: 3
# Generation 1493. Best fitness: 3. Second best: 3
# Generation 1494. Best fitness: 3. Second best: 3
# Generation 1495. Best fitness: 3. Second best: 3
# Generation 1496. Best fitness: 3. Second best: 3
# Generation 1497. Best fitness: 3. Second best: 3
# Generation 1498. Best fitness: 3. Second best: 3
# Generation 1499. Best fitness: 3. Second best: 3
# Generation 1500. Best fitness: 3. Second best: 3
# Generation 1501. Best fitness: 3. Second best: 3
# Generation 1502. Best fitness: 3. Second best: 3
# Generation 1503. Best fitness: 3. Second best: 3
# Generation 1504. Best fitness: 3. Second best: 3
# Generation 1505. Best fitness: 3. Second best: 3
# Generation 1506. Best fitness: 3. Second best: 3
# Generation 1507. Best fitness: 3. Second best: 3
# Generation 1508. Best fitness: 3. Second best: 3
# Generation 1509. Best fitness: 3. Second best: 3
# Generation 1510. Best fitness: 3. Second best: 3
# Generation 1511. Best fitness: 3. Second best: 3
# Generation 1512. Best fitness: 3. Second best: 3
# Generation 1513. Best fitness: 3. Second best: 3
# Generation 1514. Best fitness: 3. Second best: 3
# Generation 1515. Best fitness: 3. Second best: 3
# Generation 1516. Best fitness: 3. Second best: 3
# Generation 1517. Best fitness: 3. Second best: 3
# Generation 1518. Best fitness: 3. Second best: 3
# Generation 1519. Best fitness: 3. Second best: 3
# Generation 1520. Best fitness: 3. Second best: 3
# Generation 1521. Best fitness: 3. Second best: 3
# Generation 1522. Best fitness: 3. Second best: 3
# Generation 1523. Best fitness: 3. Second best: 3
# Generation 1524. Best fitness: 3. Second best: 3
# Generation 1525. Best fitness: 3. Second best: 3
# Generation 1526. Best fitness: 3. Second best: 3
# Generation 1527. Best fitness: 3. Second best: 3
# Generation 1528. Best fitness: 3. Second best: 3
# Generation 1529. Best fitness: 3. Second best: 3
# Generation 1530. Best fitness: 3. Second best: 3
# Generation 1531. Best fitness: 3. Second best: 3
# Generation 1532. Best fitness: 3. Second best: 3
# Generation 1533. Best fitness: 3. Second best: 3
# Generation 1534. Best fitness: 3. Second best: 3
# Generation 1535. Best fitness: 3. Second best: 3
# Generation 1536. Best fitness: 3. Second best: 3
# Generation 1537. Best fitness: 3. Second best: 3
# Generation 1538. Best fitness: 3. Second best: 3
# Generation 1539. Best fitness: 3. Second best: 3
# Generation 1540. Best fitness: 3. Second best: 3
# Generation 1541. Best fitness: 3. Second best: 3
# Generation 1542. Best fitness: 3. Second best: 3
# Generation 1543. Best fitness: 3. Second best: 3
# Generation 1544. Best fitness: 3. Second best: 3
# Generation 1545. Best fitness: 3. Second best: 3
# Generation 1546. Best fitness: 3. Second best: 3
# Generation 1547. Best fitness: 3. Second best: 3
# Generation 1548. Best fitness: 3. Second best: 3
# Generation 1549. Best fitness: 3. Second best: 3
# Generation 1550. Best fitness: 3. Second best: 3
# Generation 1551. Best fitness: 3. Second best: 3
# Generation 1552. Best fitness: 3. Second best: 3
# Generation 1553. Best fitness: 3. Second best: 3
# Generation 1554. Best fitness: 3. Second best: 3
# Generation 1555. Best fitness: 3. Second best: 3
# Generation 1556. Best fitness: 3. Second best: 3
# Generation 1557. Best fitness: 3. Second best: 3
# Generation 1558. Best fitness: 3. Second best: 3
# Generation 1559. Best fitness: 3. Second best: 3
# Generation 1560. Best fitness: 3. Second best: 3
# Generation 1561. Best fitness: 3. Second best: 3
# Generation 1562. Best fitness: 3. Second best: 3
# Generation 1563. Best fitness: 3. Second best: 3
# Generation 1564. Best fitness: 3. Second best: 3
# Generation 1565. Best fitness: 3. Second best: 3
# Generation 1566. Best fitness: 3. Second best: 3
# Generation 1567. Best fitness: 3. Second best: 3
# Generation 1568. Best fitness: 3. Second best: 3
# Generation 1569. Best fitness: 3. Second best: 3
# Generation 1570. Best fitness: 3. Second best: 3
# Generation 1571. Best fitness: 3. Second best: 3
# Generation 1572. Best fitness: 3. Second best: 3
# Generation 1573. Best fitness: 3. Second best: 3
# The population has gone stale. Re-seeding...
# 8 2 6 9 5 3 1 4 7
# 4 1 7 6 8 2 9 5 3
# 9 5 3 1 7 4 8 2 6
# 7 9 4 8 2 1 6 3 5
# 6 3 8 1 4 7 2 9 5
# 1 3 8 5 6 9 4 7 2
# 4 3 1 2 5 8 7 6 9
# 2 4 8 7 9 6 3 1 5
# 6 7 9 4 1 3 2 8 5
#
# Initial fitness: 13
# Generation 1575. Best fitness: 7. Second best: 7
# Generation 1576. Best fitness: 4. Second best: 7
# Generation 1577. Best fitness: 4. Second best: 5
# Generation 1578. Best fitness: 4. Second best: 5
# Generation 1579. Best fitness: 4. Second best: 5
# Generation 1580. Best fitness: 4. Second best: 5
# Generation 1581. Best fitness: 4. Second best: 5
# Generation 1582. Best fitness: 4. Second best: 5
# Generation 1583. Best fitness: 4. Second best: 5
# Generation 1584. Best fitness: 4. Second best: 5
# Generation 1585. Best fitness: 4. Second best: 5
# Generation 1586. Best fitness: 4. Second best: 5
# Generation 1587. Best fitness: 4. Second best: 5
# Generation 1588. Best fitness: 4. Second best: 5
# Generation 1589. Best fitness: 4. Second best: 5
# Generation 1590. Best fitness: 4. Second best: 5
# Generation 1591. Best fitness: 4. Second best: 5
# Generation 1592. Best fitness: 4. Second best: 5
# Generation 1593. Best fitness: 4. Second best: 5
# Generation 1594. Best fitness: 4. Second best: 5
# Generation 1595. Best fitness: 4. Second best: 4
# Generation 1596. Best fitness: 4. Second best: 4
# Generation 1597. Best fitness: 4. Second best: 4
# Generation 1598. Best fitness: 4. Second best: 4
# Generation 1599. Best fitness: 4. Second best: 4
# Generation 1600. Best fitness: 4. Second best: 4
# Generation 1601. Best fitness: 4. Second best: 4

# %%
import numpy as np
import random
import operator
from time import time

random.seed()

Nd = 9  # Number of digits (in the case of standard Sudoku puzzles, this is 9x9).

class Population(object):
    """ A set of candidate solutions to the Sudoku puzzle.
    These candidates are also known as the chromosomes in the population. """

    def __init__(self):
        self.candidates = []
        return

    def seed(self, Nc, given):
        self.candidates = []

        # Determine the legal values that each square can take.
        helper = Candidate()
        helper.values = [[[] for j in range(0, Nd)] for i in range(0, Nd)]
        for row in range(0, Nd):
            for column in range(0, Nd):
                for value in range(1, 10):
                    if ((given.values[row][column] == 0) and not (given.is_column_duplicate(column, value) or given.is_block_duplicate(row, column, value) or given.is_row_duplicate(row, value))):
                        # Value is available.
                        helper.values[row][column].append(value)
                    elif given.values[row][column] != 0:
                        # Given/known value from file.
                        helper.values[row][column].append(given.values[row][column])
                        break

        # Seed a new population.
        for p in range(0, Nc):
            g = Candidate()
            for i in range(0, Nd):  # New row in candidate.
                row = np.zeros(Nd)

                # Fill in the givens.
                for j in range(0, Nd):  # New column j value in row i.

                    # If value is already given, don't change it.
                    if given.values[i][j] != 0:
                        row[j] = given.values[i][j]
                    # Fill in the gaps using the helper board.
                    elif given.values[i][j] == 0:
                        row[j] = helper.values[i][j][random.randint(0, len(helper.values[i][j]) - 1)]

                # If we don't have a valid board, then try again. max iteration 500,000
                # There must be no duplicates in the row.
                ii = 0
                while len(list(set(row))) != Nd:
                    ii += 1
                    if ii > 500000:
                        return 0
                    for j in range(0, Nd):
                        if given.values[i][j] == 0:
                            row[j] = helper.values[i][j][random.randint(0, len(helper.values[i][j]) - 1)]

                g.values[i] = row
            # print(g.values)
            self.candidates.append(g)

        # Compute the fitness of all candidates in the population.
        self.update_fitness()

        return 1

    def update_fitness(self):
        """ Update fitness of every candidate/chromosome. """
        for candidate in self.candidates:

            candidate.update_fitness()
        return

    def sort(self):
        """ Sort the population based on fitness. """
        self.candidates = sorted(self.candidates, key=operator.attrgetter('fitness'))
        return

class Candidate(object):
    """ A candidate solutions to the Sudoku puzzle. """

    def __init__(self):
        self.values = np.zeros((Nd, Nd))
        self.fitness = None
        return

    def update_fitness(self):
        """ The fitness of a candidate solution is determined by how close it is to being the actual solution to the puzzle.
        The actual solution (i.e. the 'fittest') is defined as a 9x9 grid of numbers in the range [1, 9]
        where each row, column and 3x3 block contains the numbers [1, 9] without any duplicates (see e.g. http://www.sudoku.com/);
        if there are any duplicates then the fitness will be lower. """

        column_count = np.zeros(Nd)
        block_count = np.zeros(Nd)
        column_sum = 0
        block_sum = 0

        self.values = self.values.astype(int)
        # For each column....
        for j in range(0, Nd):
            for i in range(0, Nd):
                column_count[self.values[i][j] - 1] += 1

            for k in range(len(column_count)):
                if column_count[k] == 1:
                    column_sum += (1/Nd)/Nd
            column_count = np.zeros(Nd)

        # For each block...
        for i in range(0, Nd, 3):
            for j in range(0, Nd, 3):
                block_count[self.values[i][j] - 1] += 1
                block_count[self.values[i][j + 1] - 1] += 1
                block_count[self.values[i][j + 2] - 1] += 1

                block_count[self.values[i + 1][j] - 1] += 1
                block_count[self.values[i + 1][j + 1] - 1] += 1
                block_count[self.values[i + 1][j + 2] - 1] += 1

                block_count[self.values[i + 2][j] - 1] += 1
                block_count[self.values[i + 2][j + 1] - 1] += 1
                block_count[self.values[i + 2][j + 2] - 1] += 1

                for k in range(len(block_count)):
                    if block_count[k] == 1:
                        block_sum += (1/Nd)/Nd
                block_count = np.zeros(Nd)

        # Calculate overall fitness.
        if int(column_sum) == 1 and int(block_sum) == 1:
            fitness = 1.0
        else:
            fitness = column_sum * block_sum

        self.fitness = fitness
        return

    def mutate(self, mutation_rate, given):
        """ Mutate a candidate by picking a row, and then picking two values within that row to swap. """

        r = random.uniform(0, 1.1)
        while r > 1:  # Outside [0, 1] boundary - choose another
            r = random.uniform(0, 1.1)

        success = False
        if r < mutation_rate:  # Mutate.
            while not success:
                row1 = random.randint(0, 8)
                row2 = random.randint(0, 8)
                row2 = row1

                from_column = random.randint(0, 8)
                to_column = random.randint(0, 8)
                while from_column == to_column:
                    from_column = random.randint(0, 8)
                    to_column = random.randint(0, 8)

                    # Check if the two places are free to swap
                if given.values[row1][from_column] == 0 and given.values[row1][to_column] == 0:
                    # ...and that we are not causing a duplicate in the rows' columns.
                    if not given.is_column_duplicate(to_column, self.values[row1][from_column]) and not given.is_column_duplicate(from_column, self.values[row2][to_column]) and not given.is_block_duplicate(row2, to_column, self.values[row1][from_column]) and not given.is_block_duplicate(row1, from_column, self.values[row2][to_column]):
                        # Swap values.
                        temp = self.values[row2][to_column]
                        self.values[row2][to_column] = self.values[row1][from_column]
                        self.values[row1][from_column] = temp
                        success = True

        return success


class Fixed(Candidate):
    """ fixed/given values. """

    def __init__(self, values):
        self.values = values
        return

    def is_row_duplicate(self, row, value):
        """ Check duplicate in a row. """
        for column in range(0, Nd):
            if self.values[row][column] == value:
                return True
        return False

    def is_column_duplicate(self, column, value):
        """ Check duplicate in a column. """
        for row in range(0, Nd):
            if self.values[row][column] == value:
                return True
        return False

    def is_block_duplicate(self, row, column, value):
        """ Check duplicate in a 3 x 3 block. """
        i = 3 * (int(row / 3))
        j = 3 * (int(column / 3))

        if ((self.values[i][j] == value)
            or (self.values[i][j + 1] == value)
            or (self.values[i][j + 2] == value)
            or (self.values[i + 1][j] == value)
            or (self.values[i + 1][j + 1] == value)
            or (self.values[i + 1][j + 2] == value)
            or (self.values[i + 2][j] == value)
            or (self.values[i + 2][j + 1] == value)
            or (self.values[i + 2][j + 2] == value)):
            return True
        else:
            return False

    def make_index(self, v):
        if v <= 2:
            return 0
        elif v <= 5:
            return 3
        else:
            return 6

    def no_duplicates(self):
        for row in range(0, Nd):
            for col in range(0, Nd):
                if self.values[row][col] != 0:

                    cnt1 = list(self.values[row]).count(self.values[row][col])
                    cnt2 = list(self.values[:][col]).count(self.values[row][col])

                    block_values = [y[self.make_index(col):self.make_index(col)+3] for y in
                                    self.values[self.make_index(row):self.make_index(row)+3]]
                    block_values_ = [int(x) for y in block_values for x in y]
                    cnt3 = block_values_.count(self.values[row][col])

                    if cnt1 > 1 or cnt2 > 1 or cnt3 > 1:
                        return False
        return True

class Tournament(object):
    """ The crossover function requires two parents to be selected from the population pool. The Tournament class is used to do this.

    Two individuals are selected from the population pool and a random number in [0, 1] is chosen. If this number is less than the 'selection rate' (e.g. 0.85), then the fitter individual is selected; otherwise, the weaker one is selected.
    """

    def __init__(self):
        return

    def compete(self, candidates):
        """ Pick 2 random candidates from the population and get them to compete against each other. """
        c1 = candidates[random.randint(0, len(candidates) - 1)]
        c2 = candidates[random.randint(0, len(candidates) - 1)]
        f1 = c1.fitness
        f2 = c2.fitness

        # Find the fittest and the weakest.
        if (f1 > f2):
            fittest = c1
            weakest = c2
        else:
            fittest = c2
            weakest = c1

        # selection_rate = 0.85
        selection_rate = 0.80
        r = random.uniform(0, 1.1)
        while (r > 1):  # Outside [0, 1] boundary. Choose another.
            r = random.uniform(0, 1.1)
        if (r < selection_rate):
            return fittest
        else:
            return weakest


class CycleCrossover(object):
    """ Crossover relates to the analogy of genes within each parent candidate
    mixing together in the hopes of creating a fitter child candidate.
    Cycle crossover is used here (see e.g. A. E. Eiben, J. E. Smith.
    Introduction to Evolutionary Computing. Springer, 2007). """

    def __init__(self):
        return

    def crossover(self, parent1, parent2, crossover_rate):
        """ Create two new child candidates by crossing over parent genes. """
        child1 = Candidate()
        child2 = Candidate()

        # Make a copy of the parent genes.
        child1.values = np.copy(parent1.values)
        child2.values = np.copy(parent2.values)

        r = random.uniform(0, 1.1)
        while (r > 1):  # Outside [0, 1] boundary. Choose another.
            r = random.uniform(0, 1.1)

        # Perform crossover.
        if (r < crossover_rate):
            # Pick a crossover point. Crossover must have at least 1 row (and at most Nd-1) rows.
            crossover_point1 = random.randint(0, 8)
            crossover_point2 = random.randint(1, 9)
            while (crossover_point1 == crossover_point2):
                crossover_point1 = random.randint(0, 8)
                crossover_point2 = random.randint(1, 9)

            if (crossover_point1 > crossover_point2):
                temp = crossover_point1
                crossover_point1 = crossover_point2
                crossover_point2 = temp

            for i in range(crossover_point1, crossover_point2):
                child1.values[i], child2.values[i] = self.crossover_rows(child1.values[i], child2.values[i])

        return child1, child2

    def crossover_rows(self, row1, row2):
        child_row1 = np.zeros(Nd)
        child_row2 = np.zeros(Nd)

        remaining = [i for i in range(1, Nd + 1)]
        cycle = 0

        while ((0 in child_row1) and (0 in child_row2)):  # While child rows not complete...
            if (cycle % 2 == 0):  # Even cycles.
                # Assign next unused value.
                index = self.find_unused(row1, remaining)
                start = row1[index]
                remaining.remove(row1[index])
                child_row1[index] = row1[index]
                child_row2[index] = row2[index]
                next = row2[index]

                while (next != start):  # While cycle not done...
                    index = self.find_value(row1, next)
                    child_row1[index] = row1[index]
                    remaining.remove(row1[index])
                    child_row2[index] = row2[index]
                    next = row2[index]

                cycle += 1

            else:  # Odd cycle - flip values.
                index = self.find_unused(row1, remaining)
                start = row1[index]
                remaining.remove(row1[index])
                child_row1[index] = row2[index]
                child_row2[index] = row1[index]
                next = row2[index]

                while (next != start):  # While cycle not done...
                    index = self.find_value(row1, next)
                    child_row1[index] = row2[index]
                    remaining.remove(row1[index])
                    child_row2[index] = row1[index]
                    next = row2[index]

                cycle += 1

        return child_row1, child_row2

    def find_unused(self, parent_row, remaining):
        for i in range(0, len(parent_row)):
            if (parent_row[i] in remaining):
                return i

    def find_value(self, parent_row, value):
        for i in range(0, len(parent_row)):
            if (parent_row[i] == value):
                return i


class Sudoku(object):
    """ Solves a given Sudoku puzzle using a genetic algorithm. """

    def __init__(self):
        self.given = None
        return

    def load(self, p):
        #values = np.array(list(p.replace(".","0"))).reshape((Nd, Nd)).astype(int)
        self.given = Fixed(p)
        return

    def solve(self):

        Nc = 1000  # Number of candidates (i.e. population size).
        Ne = int(0.05 * Nc)  # Number of elites.
        Ng = 10000  # Number of generations.
        Nm = 0  # Number of mutations.

        # Mutation parameters.
        phi = 0
        sigma = 1
        mutation_rate = 0.06

        # Check given one first
        if self.given.no_duplicates() == False:
            return (-1, 1)

        # Create an initial population.
        self.population = Population()
        print("create an initial population.")
        if self.population.seed(Nc, self.given) ==  1:
            print(self.population.candidates[0].values)
            pass
        else:
            return (-1, 1)

        # For up to 10000 generations...
        stale = 0
        for generation in range(0, Ng):

            # Check for a solution.
            best_fitness = 0.0
            #best_fitness_population_values = self.population.candidates[0].values
            for c in range(0, Nc):
                fitness = self.population.candidates[c].fitness
                if (fitness == 1):
                    print("Solution found at generation %d!" % generation)
                    return (generation, self.population.candidates[c])

                # Find the best fitness and corresponding chromosome
                if (fitness > best_fitness):
                    best_fitness = fitness
                    #best_fitness_population_values = self.population.candidates[c].values

            print("Generation:", generation, " Best fitness:", best_fitness)
            #print(best_fitness_population_values)

            # Create the next population.
            next_population = []

            # Select elites (the fittest candidates) and preserve them for the next generation.
            self.population.sort()
            elites = []
            for e in range(0, Ne):
                elite = Candidate()
                elite.values = np.copy(self.population.candidates[e].values)
                elites.append(elite)

            # Create the rest of the candidates.
            for count in range(Ne, Nc, 2):
                # Select parents from population via a tournament.
                t = Tournament()
                parent1 = t.compete(self.population.candidates)
                parent2 = t.compete(self.population.candidates)

                ## Cross-over.
                cc = CycleCrossover()
                child1, child2 = cc.crossover(parent1, parent2, crossover_rate=1.0)

                # Mutate child1.
                child1.update_fitness()
                old_fitness = child1.fitness
                success = child1.mutate(mutation_rate, self.given)
                child1.update_fitness()
                if (success):
                    Nm += 1
                    if (child1.fitness > old_fitness):  # Used to calculate the relative success rate of mutations.
                        phi = phi + 1

                # Mutate child2.
                child2.update_fitness()
                old_fitness = child2.fitness
                success = child2.mutate(mutation_rate, self.given)
                child2.update_fitness()
                if (success):
                    Nm += 1
                    if (child2.fitness > old_fitness):  # Used to calculate the relative success rate of mutations.
                        phi = phi + 1

                # Add children to new population.
                next_population.append(child1)
                next_population.append(child2)

            # Append elites onto the end of the population. These will not have been affected by crossover or mutation.
            for e in range(0, Ne):
                next_population.append(elites[e])

            # Select next generation.
            self.population.candidates = next_population
            self.population.update_fitness()

            # Calculate new adaptive mutation rate (based on Rechenberg's 1/5 success rule).
            # This is to stop too much mutation as the fitness progresses towards unity.
            if (Nm == 0):
                phi = 0  # Avoid divide by zero.
            else:
                phi = phi / Nm

            if (phi > 0.2):
                sigma = sigma / 0.998
            elif (phi < 0.2):
                sigma = sigma * 0.998

            mutation_rate = abs(np.random.normal(loc=0.0, scale=sigma, size=None))

            # Check for stale population.
            self.population.sort()
            if (self.population.candidates[0].fitness != self.population.candidates[1].fitness):
                stale = 0
            else:
                stale += 1

            # Re-seed the population if 100 generations have passed
            # with the fittest two candidates always having the same fitness.
            if (stale >= 100):
                print("The population has gone stale. Re-seeding...")
                self.population.seed(Nc, self.given)
                stale = 0
                sigma = 1
                phi = 0
                mutation_rate = 0.06

        print("No solution found.")
        return (-2, 1)
    
s = Sudoku()
s.load(read_file("Test1.txt"))
start_time = time()
generation, solution = s.solve()
if (solution):
    if generation == -1:
        print("Invalid inputs")
        str_print = "Invalid input, please try to generate new game"
    elif generation == -2:
        print("No solution found")
        str_print = "No solution found, please try again"
    else:
        print(solution.values)
        time_elapsed = '{0:6.2f}'.format(time()-start_time)
        str_print = "Solution found at generation: " + str(generation) + \
                "\n" + "Time elapsed: " + str(time_elapsed) + "s"
# Out:
# create an initial population.
# [[8 4 6 3 5 9 1 2 7]
#  [9 1 7 6 8 2 5 4 3]
#  [9 5 3 1 7 4 8 2 6]
#  [7 9 4 8 2 1 6 3 5]
#  [5 6 8 4 7 3 2 9 1]
#  [1 6 9 5 3 7 4 2 8]
#  [6 3 1 2 5 8 7 4 9]
#  [2 4 8 7 9 6 3 5 1]
#  [6 7 9 4 1 3 5 8 2]]
# Generation: 0  Best fitness: 0.8097850937357142
# Generation: 1  Best fitness: 0.7466849565615026
# Generation: 2  Best fitness: 0.7669562566681938
# Generation: 3  Best fitness: 0.8097850937357142
# Generation: 4  Best fitness: 0.8332571254381987
# Generation: 5  Best fitness: 0.7863130620332297
# Generation: 6  Best fitness: 0.8097850937357142
# Generation: 7  Best fitness: 0.8122237463801282
# Generation: 8  Best fitness: 0.8332571254381987
# Generation: 9  Best fitness: 0.8518518518518553
# Generation: 10  Best fitness: 0.8332571254381987
# Generation: 11  Best fitness: 0.864197530864201
# Generation: 12  Best fitness: 0.864197530864201
# Generation: 13  Best fitness: 0.864197530864201
# Solution found at generation 14!
# [[8 2 6 9 3 5 1 4 7]
#  [4 1 7 6 8 2 9 5 3]
#  [9 5 3 1 7 4 8 2 6]
#  [7 9 4 8 2 1 6 3 5]
#  [5 6 8 3 4 7 2 9 1]
#  [1 3 2 5 6 9 4 7 8]
#  [3 4 1 2 5 8 7 6 9]
#  [2 8 5 7 9 6 3 1 4]
#  [6 7 9 4 1 3 5 8 2]]
